# %%
import pandas as pd
from IPython.display import display

# Ruta al archivo CSV
file_path = r'C:\Users\USUARIO\Desktop\nuevo\data_with_descriptors2.csv'

# Cargar el archivo CSV en un DataFrame, usando low_memory=False
df = pd.read_csv(file_path, low_memory=False)

# Mostrar las primeras filas del DataFrame con un formato agradable
display(df.head())
# Out:
#      N°         name                                         IUPAC_name  \
# 0  1059    bromoform                                          bromoform
# 1  5441  brimonidine  5-bromo-n-(4,5-dihydro-1h-imidazol-2-yl)quinox...
# 2   854        tz-19  n-(2,4,6-tribromophenyl)-4,5-dihydro-1h-imidaz...
# 3   739    4205-93-0  n-(2,6-dibromophenyl)-4,5-dihydro-1h-imidazol-...
# 4   545      methane                                            methane
#
#                           SMILES         CID  logBB BBB+/BBB-  \
# 0                      BrC(Br)Br      5558.0    NaN      BBB+
# 1    Brc1c(NC2=NCCN2)ccc2nccnc12      2435.0    NaN      BBB+
# 2  Brc1cc(Br)c(NC2=NCCN2)c(Br)c1  12406843.0   0.58      BBB+
# 3        Brc1cccc(Br)c1NC1=NCCN1  10245368.0   0.33      BBB+
# 4                              C       297.0   0.00      BBB+
#
#                                                Inchi  threshold  \
# 0                        InChI=1S/CHBr3/c2-1(3)4/h1H       -1.0
# 1  InChI=1S/C11H10BrN5/c12-9-7(17-11-15-5-6-16-11...        NaN
# 2  InChI=1S/C9H8Br3N3/c10-5-3-6(11)8(7(12)4-5)15-...        NaN
# 3  InChI=1S/C9H9Br2N3/c10-6-2-1-3-7(11)8(6)14-9-1...        NaN
# 4                                  InChI=1S/CH4/h1H4        NaN
#
#                                            reference  ...     SRW08     SRW09  \
# 0             R1|R13|R19|R6|R24|R27|R27|R27|R30|R30|  ...  5.093750  0.000000
# 1                                               R15|  ...  8.075583  6.259581
# 2         R2|R2|R8|R27|R40|R2|R2|R25|R27|R46|R47|R4|  ...  7.848153  6.259581
# 3         R2|R2|R25|R27|R46|R47|R4|R2|R2|R8|R27|R40|  ...  7.734996  6.259581
# 4  R5|R3|R21|R27|R38|R41|R40|R2|R2|R11|R12|R18|R2...  ...  0.000000  0.000000
#
#       SRW10     TSRW10          MW        AMW WPol Zagreb1  Zagreb2  mZagreb2
# 0  6.188264  24.179697  249.762836  49.952567    0    12.0      9.0  1.000000
# 1  9.736193  63.007560  291.011957  10.778221   24    90.0    106.0  3.750000
# 2  9.473704  59.989045  394.826834  17.166384   19    76.0     87.0  3.305556
# 3  9.342333  58.496842  316.916321  13.778970   17    70.0     80.0  3.138889
# 4  0.000000   1.000000   16.031300   3.206260    0     0.0      0.0  0.000000
#
# [5 rows x 749 columns]

# %%
# Verificar columnas duplicadas
def find_duplicate_columns(df):
    # Obtener nombres de columnas duplicados
    duplicates = df.columns[df.columns.duplicated()]
    
    if len(duplicates) > 0:
        print("Columnas duplicadas encontradas:")
        for column in duplicates:
            print(f"- {column}")
    else:
        print("No se encontraron columnas duplicadas.")

# Llamar a la función para verificar columnas duplicadas en el DataFrame ya cargado
find_duplicate_columns(df)
# Out:
# No se encontraron columnas duplicadas.

# %%
# Obtener el tipo de datos de cada columna
tipos_datos = df.dtypes

# Contar el número de columnas numéricas y categóricas
num_numericos = sum(tipos_datos.apply(lambda x: pd.api.types.is_numeric_dtype(x)))
num_categoricos = sum(tipos_datos.apply(lambda x: isinstance(x, pd.CategoricalDtype) or pd.api.types.is_object_dtype(x)))

# Mostrar los resultados
print(f"Cantidad de columnas numéricas: {num_numericos}")
print(f"Cantidad de columnas categóricas: {num_categoricos}")
# Out:
# Cantidad de columnas numéricas: 736
# Cantidad de columnas categóricas: 13

# %%
import pandas as pd

# Mostrar las columnas categóricas ('object')
categorical_columns = df.select_dtypes(include=['object']).columns

# Imprimir las columnas categóricas
print("Columnas categóricas:")
for col in categorical_columns:
    print(col)
# Out:
# Columnas categóricas:
# name
# IUPAC_name
# SMILES
# BBB+/BBB-
# Inchi
# reference
# group
# comments
# Tipo_SMILES
# SMILES_CANONICOS
# SMILES_ISOMERICOS
# SMILES_fixed
# SMILES_final

# %%
# Identificar columnas con datos nulos
missing_data = df.isnull().sum()

# Filtrar solo las columnas con datos nulos
missing_data = missing_data[missing_data > 0]

# Mostrar las columnas con datos nulos y la cantidad de datos nulos
print("Columnas con datos nulos y la cantidad de datos nulos:")
print(missing_data)

# Opcional: Imprimir también el porcentaje de datos nulos por columna
percentage_missing = (missing_data / len(df)) * 100
print("\nPorcentaje de datos nulos por columna:")
print(percentage_missing)
# Out:
# Columnas con datos nulos y la cantidad de datos nulos:
# name          1109
# IUPAC_name    1637
# CID           1637
# logBB         6749
# threshold     4186
# comments      7789
# dtype: int64
#
# Porcentaje de datos nulos por columna:
# name          14.205200
# IUPAC_name    20.968362
# CID           20.968362
# logBB         86.448059
# threshold     53.618547
# comments      99.769438
# dtype: float64

# %%
# Eliminar las columnas específicas que no sirven
columns_to_remove = ['threshold', 'comments']
df.drop(columns=columns_to_remove, inplace=True, errors='ignore')

# Confirmar la eliminación y mostrar el DataFrame actualizado
print("Columnas después de eliminar 'threshold' y 'comments':")
print(f"Número total de columnas después de la eliminación: {df.shape[1]}")
# Out:
# Columnas después de eliminar 'threshold' y 'comments':
# Número total de columnas después de la eliminación: 747

# %% [markdown]
#    ### Realizamos analisis y exploracion de variables categoricas

# %%
"""Analisis de Longitud"""

from scipy import stats # type: ignore

# Paso 1: Añadir Columnas de Longitud

# Añadir columnas para la longitud de cada tipo de SMILES
df['SMILES_length'] = df['SMILES'].apply(lambda x: len(str(x)) if pd.notnull(x) else 0)
df['SMILES_CANONICOS_length'] = df['SMILES_CANONICOS'].apply(lambda x: len(str(x)) if pd.notnull(x) else 0)
df['SMILES_ISOMERICOS_length'] = df['SMILES_ISOMERICOS'].apply(lambda x: len(str(x)) if pd.notnull(x) else 0)

# Paso 2: Visualizar la Distribución de la Longitud

import seaborn as sns # type: ignore
import matplotlib.pyplot as plt

# Configurar el estilo del gráfico
sns.set(style="whitegrid")

# Crear un gráfico de distribución para cada tipo de SMILES
fig, axes = plt.subplots(3, 1, figsize=(12, 18), sharex=True)

# Distribución para SMILES
sns.histplot(data=df, x='SMILES_length', hue='BBB+/BBB-', kde=True, ax=axes[0])
axes[0].set_title("Distribución de la Longitud de SMILES por Clase BBB+/BBB-")
axes[0].set_xlabel("Longitud de SMILES")
axes[0].set_ylabel("Frecuencia")

# Distribución para SMILES_CANONICOS
sns.histplot(data=df, x='SMILES_CANONICOS_length', hue='BBB+/BBB-', kde=True, ax=axes[1])
axes[1].set_title("Distribución de la Longitud de SMILES_CANONICOS por Clase BBB+/BBB-")
axes[1].set_xlabel("Longitud de SMILES_CANONICOS")
axes[1].set_ylabel("Frecuencia")

# Distribución para SMILES_ISOMERICOS
sns.histplot(data=df, x='SMILES_ISOMERICOS_length', hue='BBB+/BBB-', kde=True, ax=axes[2])
axes[2].set_title("Distribución de la Longitud de SMILES_ISOMERICOS por Clase BBB+/BBB-")
axes[2].set_xlabel("Longitud de SMILES_ISOMERICOS")
axes[2].set_ylabel("Frecuencia")

# Ajustar el layout
plt.tight_layout()
plt.show()


from scipy import stats # type: ignore

# Calcular estadísticas descriptivas para SMILES
length_stats_smiles = df.groupby('BBB+/BBB-')['SMILES_length'].describe()
print("Estadísticas descriptivas para SMILES:")
print(length_stats_smiles)

# Calcular estadísticas descriptivas para SMILES_CANONICOS
length_stats_canonicos = df.groupby('BBB+/BBB-')['SMILES_CANONICOS_length'].describe()
print("\nEstadísticas descriptivas para SMILES_CANONICOS:")
print(length_stats_canonicos)

# Calcular estadísticas descriptivas para SMILES_ISOMERICOS
length_stats_isomericos = df.groupby('BBB+/BBB-')['SMILES_ISOMERICOS_length'].describe()
print("\nEstadísticas descriptivas para SMILES_ISOMERICOS:")
print(length_stats_isomericos)
# Out:
# Estadísticas descriptivas para SMILES:
#             count       mean        std  min   25%   50%   75%    max
# BBB+/BBB-
# BBB+       4956.0  49.213882  24.476819  1.0  33.0  44.0  59.0  256.0
# BBB-       2851.0  71.915468  43.547420  4.0  45.0  61.0  85.0  383.0
#
# Estadísticas descriptivas para SMILES_CANONICOS:
#             count       mean        std  min   25%   50%   75%    max
# BBB+/BBB-
# BBB+       4956.0  41.208838  16.622641  1.0  30.0  39.0  51.0  167.0
# BBB-       2851.0  58.224833  28.224134  4.0  41.0  53.0  68.0  254.0
#
# Estadísticas descriptivas para SMILES_ISOMERICOS:
#             count       mean        std  min   25%   50%   75%    max
# BBB+/BBB-
# BBB+       4956.0  49.211259  24.472047  1.0  33.0  44.0  59.0  256.0
# BBB-       2851.0  71.949491  43.568292  4.0  45.0  61.0  85.0  382.0

# %% [markdown]
# Las estadísticas muestran que las longitudes medias de los SMILES son más largas para las moléculas que atraviesan la barrera hematoencefálica (BBB+), en comparación con las que no la atraviesan (BBB-). Esto es consistente en todas las variantes (SMILES, SMILES_CANONICOS, y SMILES_ISOMERICOS), con una mayor variabilidad en las longitudes para las moléculas BBB+. La gráfica confirma que los SMILES para BBB+ tienden a ser más largos.

# %%
"""Análisis de la Simetría Molecular en Relación con la Permeabilidad a la Barrera Hematoencefálica"""

import pandas as pd
from rdkit import Chem  # Importar Chem de rdkit
from rdkit.Chem import rdMolDescriptors  # Importar los descriptores moleculares
import matplotlib.pyplot as plt
import seaborn as sns


# Función para calcular la simetría de una molécula
def calculate_symmetry(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        # Calcular la simetría basada en el número de anillos como proxy
        symmetry = rdMolDescriptors.CalcNumRings(mol)
        return symmetry
    return None

# Aplicar la función a cada SMILES
df['Symmetry'] = df['SMILES'].apply(calculate_symmetry)

# Estadísticas descriptivas de simetría
symmetry_stats = df.groupby('BBB+/BBB-')['Symmetry'].describe()

# Mostrar resultados
print("Estadísticas descriptivas de simetría:")
print(symmetry_stats)

# Visualización de la distribución de simetría
plt.figure(figsize=(12, 6))
sns.boxplot(x='BBB+/BBB-', y='Symmetry', data=df)
plt.title('Distribución de Simetría por Clase (BBB+/BBB-)')
plt.xlabel('Clase (BBB+/BBB-)')
plt.ylabel('Simetría')
plt.show()
# Out:
# Estadísticas descriptivas de simetría:
#             count      mean       std  min  25%  50%  75%   max
# BBB+/BBB-
# BBB+       4956.0  3.202785  1.543399  0.0  2.0  3.0  4.0   9.0
# BBB-       2851.0  3.379867  1.718180  0.0  2.0  3.0  4.0  16.0

# %% [markdown]
# Las estadísticas descriptivas de simetría muestran que, en promedio, las moléculas que atraviesan la barrera hematoencefálica (BBB+) tienen una simetría de 3.20, mientras que las que no la atraviesan (BBB-) tienen una simetría promedio de 3.38. Ambas clases tienen valores mínimos de 0, con una máxima de 9 para BBB+ y 16 para BBB-. La desviación estándar es similar en ambas clases, indicando una distribución relativamente homogénea en términos de simetría.

# %%
# Función para determinar la quiralidad de una molécula
def is_chiral(smiles):
    mol = Chem.MolFromSmiles(smiles)
    return any(atom.HasProp('_ChiralityPossible') for atom in mol.GetAtoms())

# Aplicar la función y crear una columna 'Is_Chiral'
df['Is_Chiral'] = df['SMILES'].apply(is_chiral)

# Contar el número de moléculas quirales por clase
chiral_counts = df.groupby('BBB+/BBB-')['Is_Chiral'].sum()
total_counts = df.groupby('BBB+/BBB-').size()
chiral_percentage = (chiral_counts / total_counts) * 100

print("Número de moléculas quirales por clase:")
print(chiral_counts)
print("\nPorcentaje de moléculas quirales por clase:")
print(chiral_percentage)

# Visualización de la distribución de quiralidad
import seaborn as sns # type: ignore
import matplotlib.pyplot as plt # type: ignore

plt.figure(figsize=(8, 6))
sns.countplot(x='BBB+/BBB-', hue='Is_Chiral', data=df)
plt.title('Distribución de Quiralidad por Clase (BBB+/BBB-)')
plt.xlabel('Clase (BBB+/BBB-)')
plt.ylabel('Número de Moléculas')
plt.legend(title='¿Es Quiral?')
plt.show()
# Out:
# Número de moléculas quirales por clase:
# BBB+/BBB-
# BBB+    3716
# BBB-    2363
# Name: Is_Chiral, dtype: int64
#
# Porcentaje de moléculas quirales por clase:
# BBB+/BBB-
# BBB+    74.979822
# BBB-    82.883199
# dtype: float64

# %% [markdown]
# En la clase BBB+ hay 3,716 moléculas quirales, representando el 75% del total, mientras que en la clase BBB- hay 2,363, que constituye el 83% del total.

# %%
import pandas as pd
from collections import Counter

# Concatenar todos los SMILES en una sola cadena
all_smiles = ' '.join(df['SMILES'].dropna())

# Contar combinaciones de 2 y 3 caracteres
def count_combinations(text, n):
    return Counter(text[i:i+n] for i in range(len(text) - n + 1))

# Contar combinaciones de 2 y 3 caracteres
bigram_counts = count_combinations(all_smiles, 2)
trigram_counts = count_combinations(all_smiles, 3)

# Buscar combinaciones específicas
def search_combinations(counter, queries):
    return {query: counter.get(query, 0) for query in queries}

# Combinaciones específicas a buscar
specific_combinations = ['Br', 'Cl', 'F', 'I', 'N+', 'OH']

# Mostrar las combinaciones más comunes
print("Combinaciones de 2 caracteres más comunes:")
for combo, count in bigram_counts.most_common(20):
    print(f'{combo}: {count}')

print("\nCombinaciones de 3 caracteres más comunes:")
for combo, count in trigram_counts.most_common(20):
    print(f'{combo}: {count}')

# Mostrar conteo de combinaciones específicas
print("\nConteo de combinaciones específicas:")
specific_counts = search_combinations(bigram_counts, specific_combinations)
for combo, count in specific_counts.items():
    print(f'{combo}: {count}')
# Out:
# Combinaciones de 2 caracteres más comunes:
# cc: 25313
# CC: 22334
# O): 19939
# C(: 18266
# [C: 17889
# C@: 17882
# (C: 15626
# H]: 15277
# @H: 14741
# )C: 14695
# =O: 12820
# (=: 11556
# C): 10908
# @@: 8696
# c1: 8379
# )c: 7979
# ](: 7632
# (O: 7538
# c(: 6991
# )[: 6660
#
# Combinaciones de 3 caracteres más comunes:
# [C@: 17882
# @H]: 14741
# ccc: 14288
# =O): 12285
# (=O: 11237
# C(=: 10122
# C@@: 8685
# (C): 8353
# C@H: 7844
# H](: 7017
# @@H: 6897
# O)C: 6824
# CCC: 6445
# )[C: 6381
# C[C: 5847
# (O): 5532
# CC(: 4565
# C(C: 4549
# C)C: 4437
# c1c: 4100
#
# Conteo de combinaciones específicas:
# Br: 160
# Cl: 1823
# F: 0
# I: 0
# N+: 278
# OH: 0

# %%
# Concatenar todos los SMILES en una sola cadena
all_smiles = ''.join(df['SMILES'].dropna())

# Contar la frecuencia de cada carácter
char_freq = Counter(all_smiles)

# Convertir el Counter a DataFrame para visualización
char_freq_df = pd.DataFrame.from_dict(char_freq, orient='index').reset_index()
char_freq_df.columns = ['Character', 'Frequency']

# Ordenar por frecuencia
char_freq_df = char_freq_df.sort_values(by='Frequency', ascending=False)

# Mostrar las primeras filas del DataFrame
print(char_freq_df.head())

# Visualizar las frecuencias de los caracteres
plt.figure(figsize=(12, 6))
sns.barplot(x='Character', y='Frequency', data=char_freq_df)
plt.title('Frecuencia de Caracteres en SMILES')
plt.xlabel('Caracter')
plt.ylabel('Frecuencia')
plt.xticks(rotation=90)
plt.show()
# Out:
#    Character  Frequency
# 2          C     103574
# 5          c      53347
# 3          (      42477
# 4          )      42477
# 12         O      31015

# %%
# Verificar que df contenga las columnas necesarias
if 'SMILES' not in df.columns or 'BBB+/BBB-' not in df.columns:
    raise ValueError("El DataFrame no contiene las columnas 'SMILES' o 'BBB+/BBB-'")

# Función para calcular la frecuencia de caracteres
def calculate_char_frequency(df):
    all_chars = ''.join(df['SMILES'])
    return Counter(all_chars)

# Función para generar el informe textual
def generate_report(counter, top_n=10):
    most_common = counter.most_common(top_n)
    least_common = counter.most_common()[:-top_n-1:-1]
    
    print("Frecuencia de Caracteres:")
    print("\nMás comunes:")
    for char, count in most_common:
        print(f'{char}: {count}')
    
    print("\nMenos comunes:")
    for char, count in least_common:
        print(f'{char}: {count}')
    
    return most_common, least_common

# Preparar la visualización
plt.figure(figsize=(12, 12))

# Obtener las categorías de BBB+/BBB-
categories = df['BBB+/BBB-'].unique()
colors = ['skyblue', 'lightpink']  # Colores para las diferentes categorías

# Crear un gráfico para cada categoría
for i, (label, color) in enumerate(zip(categories, colors), start=1):
    plt.subplot(len(categories), 1, i)  # Crear un subplot por categoría
    subset = df[df['BBB+/BBB-'] == label]
    char_count = calculate_char_frequency(subset)
    
    # Generar informe textual para la categoría
    print(f"\nCategoría: {label}")
    generate_report(char_count)
    
    # Visualización
    plt.bar(char_count.keys(), char_count.values(), alpha=0.7, color=color)
    plt.xlabel('Caracteres')
    plt.ylabel('Frecuencia')
    plt.title(f'Frecuencia de Caracteres en SMILES - BBB+/BBB- {label}')
    plt.xticks(rotation=90)
    plt.grid(True, linestyle='--', alpha=0.7)

# Ajustar el espaciado entre subplots
plt.tight_layout()
plt.show()
# Out:
# Categoría: BBB+
# Frecuencia de Caracteres:
#
# Más comunes:
# C: 59894
# c: 33537
# (: 20680
# ): 20680
# O: 14041
# @: 13801
# 1: 13470
# [: 9870
# ]: 9870
# 2: 9510
#
# Menos comunes:
# X: 1
# i: 1
# L: 1
# K: 1
# A: 1
# e: 2
# .: 3
# I: 18
# P: 19
# 6: 52
#
# Categoría: BBB-
# Frecuencia de Caracteres:
#
# Más comunes:
# C: 43680
# (: 21797
# ): 21797
# c: 19810
# O: 16974
# @: 12795
# =: 9301
# [: 9156
# ]: 9156
# H: 8173
#
# Menos comunes:
# i: 1
# 9: 2
# .: 8
# 8: 20
# r: 32
# B: 32
# 7: 38
# P: 47
# I: 66
# #: 108

# %% [markdown]
# En la categoría BBB+, los caracteres más frecuentes son C (carbono), c (carbono aromático), ( y ) (delimitadores de anillos), y O (oxígeno), indicando la alta presencia de estos elementos en las moléculas. Los menos comunes, como X y i, no tienen significados estándar universales en SMILES pero pueden representar átomos o estructuras específicas. En BBB-, i y 9 son raros; i puede marcar posiciones en anillos, y 9 podría estar relacionado con numeraciones específicas en estructuras personalizadas.

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Verificar que df contenga las columnas necesarias
if 'SMILES' not in df.columns or 'BBB+/BBB-' not in df.columns:
    raise ValueError("El DataFrame no contiene las columnas 'SMILES' o 'BBB+/BBB-'")

# Función para calcular la polaridad (momento dipolar) de una molécula
def calculate_polarity(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        return Descriptors.MolLogP(mol)  # Aquí usamos el LogP como proxy de polaridad
    return None

# Aplicar la función a cada SMILES
df['Polarity'] = df['SMILES'].apply(calculate_polarity)

# Estadísticas descriptivas de polaridad
polar_stats = df.groupby('BBB+/BBB-')['Polarity'].describe()

# Mostrar estadísticas descriptivas
print("Estadísticas descriptivas de polaridad:")
print(polar_stats)

# Visualización de la distribución de polaridad
plt.figure(figsize=(12, 6))

# Histogramas de polaridad por clase
sns.histplot(data=df, x='Polarity', hue='BBB+/BBB-', multiple='stack', palette='pastel', bins=30)
plt.title('Distribución de Polaridad por Clase (BBB+/BBB-)')
plt.xlabel('Polaridad')
plt.ylabel('Frecuencia')
plt.show()

plt.figure(figsize=(12, 6))

# Boxplot de polaridad por clase
sns.boxplot(x='BBB+/BBB-', y='Polarity', data=df, palette='pastel', hue='BBB+/BBB-', showfliers=False)
plt.title('Distribución de Polaridad por Clase (BBB+/BBB-)')
plt.xlabel('Clase (BBB+/BBB-)')
plt.ylabel('Polaridad')
plt.show()

# Análisis de Polaridad:

# Para la categoría BBB+, la polaridad media es 2.87 con una desviación estándar de 1.58. 
# La polaridad varía desde un mínimo de -4.38 hasta un máximo de 10.06, con el 25% de los valores por debajo de 1.84 
# y el 75% por debajo de 3.96.

# En contraste, para BBB-, la polaridad media es 1.46 con una desviación estándar de 2.76. Los valores van desde -8.90 
# hasta 12.61, con el 25% de los valores por debajo de 0.00 y el 75% por debajo de 3.11.

# Conclusiones: Las moléculas en la categoría BBB+ tienden a tener una mayor polaridad media y menor variabilidad en comparación 
# con las de BBB-. La gama de polaridad es más amplia en BBB-, lo que sugiere una mayor diversidad en las propiedades de polaridad 
# de estas moléculas.
# Out:
# Estadísticas descriptivas de polaridad:
#             count      mean       std     min     25%     50%     75%      max
# BBB+/BBB-
# BBB+       4956.0  2.874041  1.578878 -4.3754  1.8437  2.9233  3.9625  10.0563
# BBB-       2851.0  1.455545  2.755004 -8.8953  0.0013  1.4582  3.1111  12.6058

# %% [markdown]
# Análisis de Polaridad:
#
#
# """
# Para la categoría BBB+, la polaridad media es 2.87 con una desviación estándar de 1.58.
# La polaridad varía desde un mínimo de -4.38 hasta un máximo de 10.06, con el 25% de los valores por debajo de 1.84
# y el 75% por debajo de 3.96.
#
# En contraste, para BBB-, la polaridad media es 1.46 con una desviación estándar de 2.76. Los valores van desde -8.90
# hasta 12.61, con el 25% de los valores por debajo de 0.00 y el 75% por debajo de 3.11.
#
# Conclusiones: Las moléculas en la categoría BBB+ tienden a tener una mayor polaridad media y menor variabilidad en comparación
# con las de BBB-. La gama de polaridad es más amplia en BBB-, lo que sugiere una mayor diversidad en las propiedades de polaridad  de estas moléculas.
# """

# %%
from rdkit import Chem
from rdkit.Chem import AllChem
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Función para calcular las cargas explícitas usando el modelo de Gasteiger
def calculate_explicit_charges(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        # Añadir hidrógenos para obtener cargas correctas
        mol = Chem.AddHs(mol)
        AllChem.ComputeGasteigerCharges(mol)  # Calcular cargas Gasteiger
        charges = []
        for atom in mol.GetAtoms():
            charge = atom.GetProp('_GasteigerCharge')
            charges.append(float(charge))  # Convertir a tipo float
        return charges
    return []

# Aplicar la función a cada SMILES
df['ExplicitCharges'] = df['SMILES'].apply(calculate_explicit_charges)

# Función para comprobar las propiedades atómicas
def check_atom_properties(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        mol = Chem.AddHs(mol)
        AllChem.ComputeGasteigerCharges(mol)
        properties = set()
        for atom in mol.GetAtoms():
            properties.update(atom.GetPropsAsDict().keys())
        return properties
    return set()

# Comprobar propiedades para un SMILES de ejemplo
sample_smiles = df['SMILES'].iloc[0]
print("Propiedades atómicas del primer SMILES:")
print(check_atom_properties(sample_smiles))

# Expandir la lista de cargas explícitas en un formato que permita el análisis
df_expanded = df.copy()
df_expanded = df_expanded.explode('ExplicitCharges')  # Expandir la lista de cargas

# Convertir las cargas a tipo numérico
df_expanded['ExplicitCharges'] = pd.to_numeric(df_expanded['ExplicitCharges'], errors='coerce')

# Estadísticas descriptivas de cargas explícitas por categoría
charge_stats = df_expanded.groupby('BBB+/BBB-')['ExplicitCharges'].describe()

# Mostrar estadísticas descriptivas
print("Estadísticas descriptivas de cargas explícitas:")
print(charge_stats)

# Configuración del estilo del gráfico
sns.set(style="whitegrid")

# Visualización de la distribución de cargas explícitas por categoría
plt.figure(figsize=(12, 6))
sns.boxplot(x='BBB+/BBB-', y='ExplicitCharges', data=df_expanded, hue='BBB+/BBB-', palette='pastel')
plt.title('Distribución de Cargas Explícitas por Clase (BBB+/BBB-)')
plt.xlabel('Clase (BBB+/BBB-)')
plt.ylabel('Carga Explícita')
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.7)

# Mostrar el gráfico
plt.show()
# Out:
# Propiedades atómicas del primer SMILES:
# {'_GasteigerHCharge', '__computedProps', '_GasteigerCharge', 'isImplicit'}
# Estadísticas descriptivas de cargas explícitas:
#               count      mean       std       min       25%       50%  \
# BBB+/BBB-
# BBB+       233634.0  0.000094  0.130554 -0.754605 -0.031386  0.028042
# BBB-       173470.0  0.000686  0.162931 -0.739367 -0.035873  0.032403
#
#                 75%       max
# BBB+/BBB-
# BBB+       0.061877  0.572607
# BBB-       0.066951  0.554222

# %%
from rdkit import Chem
from rdkit.Chem import AllChem
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Función para calcular las cargas explícitas usando el modelo de Gasteiger
def calculate_explicit_charges(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        # Añadir hidrógenos para obtener cargas correctas
        mol = Chem.AddHs(mol)
        AllChem.ComputeGasteigerCharges(mol)  # Calcular cargas Gasteiger
        charges = []
        for atom in mol.GetAtoms():
            charge = atom.GetProp('_GasteigerCharge')
            charges.append(float(charge))  # Convertir a tipo float
        return charges
    return []

# Aplicar la función a cada SMILES
df['ExplicitCharges'] = df['SMILES'].apply(calculate_explicit_charges)

# Función para comprobar las propiedades atómicas
def check_atom_properties(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        mol = Chem.AddHs(mol)
        AllChem.ComputeGasteigerCharges(mol)
        properties = set()
        for atom in mol.GetAtoms():
            properties.update(atom.GetPropsAsDict().keys())
        return properties
    return set()

# Comprobar propiedades para un SMILES de ejemplo
sample_smiles = df['SMILES'].iloc[0]
print("Propiedades atómicas del primer SMILES:")
print(check_atom_properties(sample_smiles))

# Expandir la lista de cargas explícitas en un formato que permita el análisis
df_expanded = df.copy()
df_expanded = df_expanded.explode('ExplicitCharges')  # Expandir la lista de cargas

# Convertir las cargas a tipo numérico
df_expanded['ExplicitCharges'] = pd.to_numeric(df_expanded['ExplicitCharges'], errors='coerce')

# Estadísticas descriptivas de cargas explícitas por categoría
charge_stats = df_expanded.groupby('BBB+/BBB-')['ExplicitCharges'].describe()

# Mostrar estadísticas descriptivas
print("Estadísticas descriptivas de cargas explícitas:")
print(charge_stats)

# Configuración del estilo del gráfico
sns.set(style="whitegrid")

# Visualización de la distribución de cargas explícitas por categoría
plt.figure(figsize=(12, 6))
sns.boxplot(x='BBB+/BBB-', y='ExplicitCharges', data=df_expanded, hue='BBB+/BBB-', palette='pastel')
plt.title('Distribución de Cargas Explícitas por Clase (BBB+/BBB-)')
plt.xlabel('Clase (BBB+/BBB-)')
plt.ylabel('Carga Explícita')
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.7)

# Mostrar el gráfico
plt.show()
# Out:
# Propiedades atómicas del primer SMILES:
# {'_GasteigerHCharge', '__computedProps', '_GasteigerCharge', 'isImplicit'}
# Estadísticas descriptivas de cargas explícitas:
#               count      mean       std       min       25%       50%  \
# BBB+/BBB-
# BBB+       233634.0  0.000094  0.130554 -0.754605 -0.031386  0.028042
# BBB-       173470.0  0.000686  0.162931 -0.739367 -0.035873  0.032403
#
#                 75%       max
# BBB+/BBB-
# BBB+       0.061877  0.572607
# BBB-       0.066951  0.554222

# %% [markdown]
# Estadísticas Descriptivas de Cargas Explícitas
# Estadísticas Descriptivas:
#
# Para las cargas explícitas en las categorías BBB+ y BBB-:
#
# BBB+: La carga media es de 0.000094 con una desviación estándar de 0.130554. Las cargas varían entre -0.754605 y 0.572607, con el 25% de los valores por debajo de -0.031386 y el 75% por debajo de 0.061877.
#
# BBB-: La carga media es de 0.000686 con una desviación estándar de 0.162931. Las cargas van desde -0.739367 hasta 0.554222, con el 25% de los valores por debajo de -0.035873 y el 75% por debajo de 0.066951.
#
# Conclusiones:
#
# Las cargas explícitas en ambas categorías tienen una media muy cercana a cero, pero BBB- muestra una mayor desviación estándar, indicando una mayor variabilidad en las cargas. Las distribuciones de cargas son relativamente similares entre las dos categorías, aunque BBB- tiene un rango ligeramente más amplio.

# %%
# Verificar que df contenga las columnas necesarias
if 'SMILES' not in df.columns or 'BBB+/BBB-' not in df.columns:
    raise ValueError("El DataFrame no contiene las columnas 'SMILES' o 'BBB+/BBB-'")

# Función para contar enlaces dobles en un SMILES
def count_double_bonds(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        num_double_bonds = len([bond for bond in mol.GetBonds() if bond.GetBondTypeAsDouble() == 2.0])
        return num_double_bonds
    return None

# Calcular el número de enlaces dobles
df['DoubleBonds'] = df['SMILES'].apply(count_double_bonds)

# Estadísticas descriptivas de enlaces dobles
print("Estadísticas Descriptivas de Enlaces Dobles:")
print(df.groupby('BBB+/BBB-')['DoubleBonds'].describe())

# Configuración del gráfico
plt.figure(figsize=(12, 6))

# Usar `hue` para asignar colores a las categorías y ajustar la leyenda
sns.boxplot(x='BBB+/BBB-', y='DoubleBonds', data=df, hue='BBB+/BBB-', palette='pastel')

# Configuración de etiquetas y título
plt.xlabel('Categoría BBB+/BBB-')
plt.ylabel('Número de Enlaces Dobles')
plt.title('Número de Enlaces Dobles en relación a BBB+/BBB-')
plt.grid(True, linestyle='--', alpha=0.7)


# Mostrar el gráfico
plt.show()
# Out:
# Estadísticas Descriptivas de Enlaces Dobles:
#             count      mean       std  min  25%  50%  75%   max
# BBB+/BBB-
# BBB+       4956.0  1.862389  1.751237  0.0  1.0  1.0  3.0  12.0
# BBB-       2851.0  3.262364  2.469161  0.0  1.0  3.0  5.0  16.0

# %% [markdown]
# Análisis de Enlaces Dobles
# Estadísticas Descriptivas:
#
# Para la categoría BBB+, el número medio de enlaces dobles es 1.86, con una desviación estándar de 1.75. Los valores varían desde un mínimo de 0 hasta un máximo de 12. El 25% de las moléculas tienen 1 enlace doble o menos, y el 75% tienen hasta 3 enlaces dobles.
#
# En contraste, para BBB-, la media de enlaces dobles es significativamente mayor, 3.26, con una desviación estándar de 2.47. Los valores oscilan entre 0 y 16. El 25% de las moléculas tienen hasta 1 enlace doble, mientras que el 75% tienen hasta 5 enlaces dobles.
#
# Conclusiones:
#
# Las moléculas en la categoría BBB- tienden a tener más enlaces dobles en comparación con las de BBB+. La variabilidad en el número de enlaces dobles es también mayor en BBB-, lo que indica una mayor diversidad en la estructura de las moléculas de esta categoría. En comparación, las moléculas en BBB+ muestran una distribución más concentrada en torno a un menor número de enlaces dobles, sugiriendo menos diversidad en sus estructuras en este aspecto.
#
# Esta diferencia podría implicar que la presencia de enlaces dobles tiene un efecto sobre la capacidad de las moléculas para atravesar la barrera hematoencefálica, lo que puede ser relevante para la predicción de sus propiedades.

# %%
# Función para contar átomos y enlaces en un SMILES
def count_atoms_and_bonds(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        num_atoms = mol.GetNumAtoms()
        num_bonds = mol.GetNumBonds()
        return num_atoms, num_bonds
    return None, None

# Aplicar la función y crear nuevas columnas en el DataFrame
df[['NumAtoms', 'NumBonds']] = df['SMILES'].apply(lambda smiles: pd.Series(count_atoms_and_bonds(smiles)))

# Visualización de la relación entre el número de átomos/enlaces y BBB+/BBB-

plt.figure(figsize=(12, 6))

# Número de Átomos
plt.subplot(1, 2, 1)
sns.boxplot(x='BBB+/BBB-', y='NumAtoms', data=df)
plt.xlabel('Categoría BBB+/BBB-')
plt.ylabel('Número de Átomos')
plt.title('Número de Átomos en relación a BBB+/BBB-')

# Número de Enlaces
plt.subplot(1, 2, 2)
sns.boxplot(x='BBB+/BBB-', y='NumBonds', data=df)
plt.xlabel('Categoría BBB+/BBB-')
plt.ylabel('Número de Enlaces')
plt.title('Número de Enlaces en relación a BBB+/BBB-')

plt.tight_layout()
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# Estadísticas descriptivas para el número de átomos
stats_atoms = df.groupby('BBB+/BBB-')['NumAtoms'].describe()

# Estadísticas descriptivas para el número de enlaces
stats_bonds = df.groupby('BBB+/BBB-')['NumBonds'].describe()

print("Estadísticas Descriptivas para el Número de Átomos:")
print(stats_atoms)
print("\nEstadísticas Descriptivas para el Número de Enlaces:")
print(stats_bonds)
# Out:
# Estadísticas Descriptivas para el Número de Átomos:
#             count       mean        std  min   25%   50%   75%    max
# BBB+/BBB-
# BBB+       4956.0  23.908797   8.542891  1.0  19.0  23.0  29.0   85.0
# BBB-       2851.0  32.101017  15.037858  4.0  23.0  29.0  37.0  136.0
#
# Estadísticas Descriptivas para el Número de Enlaces:
#             count       mean        std  min   25%   50%   75%    max
# BBB+/BBB-
# BBB+       4956.0  26.087974   9.677104  0.0  20.0  26.0  32.0   85.0
# BBB-       2851.0  34.445808  16.199051  3.0  25.0  31.0  40.0  145.0

# %% [markdown]
# Las moléculas que no atraviesan la barrera hematoencefálica (BBB-) presentan en promedio más átomos (32.10) y enlaces (34.45) en comparación con las que sí la atraviesan (BBB+) (23.91 átomos y 26.09 enlaces). Además, la mayor desviación estándar en el grupo BBB- indica una mayor variabilidad en tamaño y complejidad. Estos hallazgos sugieren que las moléculas más grandes y complejas tienden a no atravesar la barrera. Considerar estas diferencias puede ser crucial para mejorar modelos predictivos sobre la permeabilidad de las moléculas a través de la barrera hematoencefálica. Explorar otros descriptores moleculares también podría ofrecer más información para optimizar las predicciones.

# %%
# Función para contar el número de anillos en un SMILES
def ring_count(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        ring_info = mol.GetRingInfo()
        return len(ring_info.AtomRings())
    return None

# Aplicar la función y crear una nueva columna en el DataFrame
df['RingCount'] = df['SMILES'].apply(ring_count)

# Agrupar por BBB+/BBB- y calcular estadísticas básicas
ring_count_stats = df.groupby('BBB+/BBB-')['RingCount'].describe()
print("\nEstadísticas de Número de Anillos:")
print(ring_count_stats)
# Out:
# Estadísticas de Número de Anillos:
#             count      mean       std  min  25%  50%  75%   max
# BBB+/BBB-
# BBB+       4956.0  3.202785  1.543399  0.0  2.0  3.0  4.0   9.0
# BBB-       2851.0  3.379867  1.718180  0.0  2.0  3.0  4.0  16.0

# %% [markdown]
# Las estadísticas del número de anillos revelan que las moléculas en la categoría BBB+ tienen un promedio de 3.20 anillos con una desviación estándar de 1.54. En comparación, las moléculas en la categoría BBB- presentan un promedio ligeramente mayor de 3.38 anillos y una desviación estándar de 1.72. Ambos grupos tienen un rango similar en el número de anillos, con valores mínimos de 0 y máximos de 9 para BBB+ y 16 para BBB-. La distribución muestra que las moléculas en ambas categorías tienden a tener entre 2 y 4 anillos en la mayoría de los casos, pero las moléculas BBB- presentan una mayor variabilidad en el número máximo de anillos.

# %%
# Función para contar átomos y enlaces en un SMILES
def count_atoms_and_bonds(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        num_atoms = mol.GetNumAtoms()
        num_bonds = mol.GetNumBonds()
        return num_atoms, num_bonds
    return None, None

# Aplicar la función y crear nuevas columnas en el DataFrame
df[['NumAtoms', 'NumBonds']] = df['SMILES'].apply(lambda smiles: pd.Series(count_atoms_and_bonds(smiles)))

# Agrupar por BBB+/BBB- y calcular estadísticas básicas
atoms_bonds_stats = df.groupby('BBB+/BBB-')[['NumAtoms', 'NumBonds']].describe().transpose()
print("Estadísticas de Número de Átomos y Enlaces:")
print(atoms_bonds_stats)

# Función para calcular el grado de conectividad promedio
def average_connectivity(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        degrees = [atom.GetDegree() for atom in mol.GetAtoms()]
        return sum(degrees) / len(degrees) if degrees else None
    return None

# Aplicar la función y crear una nueva columna en el DataFrame
df['AvgConnectivity'] = df['SMILES'].apply(average_connectivity)

# Agrupar por BBB+/BBB- y calcular estadísticas básicas
connectivity_stats = df.groupby('BBB+/BBB-')['AvgConnectivity'].describe()
print("\nEstadísticas de Conectividad Promedio:")
print(connectivity_stats)

# Función para calcular el número de anillos en un SMILES
def ring_count(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        ring_info = mol.GetRingInfo()
        return len(ring_info.AtomRings())
    return None

# Aplicar la función y crear una nueva columna en el DataFrame
df['RingCount'] = df['SMILES'].apply(ring_count)

# Agrupar por BBB+/BBB- y calcular estadísticas básicas
ring_count_stats = df.groupby('BBB+/BBB-')['RingCount'].describe()
print("\nEstadísticas de Número de Anillos:")
print(ring_count_stats)

# Función para contar el número de enlaces rotacionales en un SMILES
def rotatable_bond_count(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        return Descriptors.NumRotatableBonds(mol)  # type: ignore
    return None

# Aplicar la función y crear una nueva columna en el DataFrame
df['RotatableBonds'] = df['SMILES'].apply(rotatable_bond_count)

# Agrupar por BBB+/BBB- y calcular estadísticas básicas
rotatable_bond_stats = df.groupby('BBB+/BBB-')['RotatableBonds'].describe()
print("\nEstadísticas de Enlaces Rotacionales:")
print(rotatable_bond_stats)

# Función para contar el número de enlaces múltiples en un SMILES
def multiple_bonds_count(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        return sum(1 for bond in mol.GetBonds() if bond.GetBondTypeAsDouble() > 1.0)
    return None

# Aplicar la función y crear una nueva columna en el DataFrame
df['MultipleBonds'] = df['SMILES'].apply(multiple_bonds_count)

# Agrupar por BBB+/BBB- y calcular estadísticas básicas
multiple_bonds_stats = df.groupby('BBB+/BBB-')['MultipleBonds'].describe()
print("\nEstadísticas de Enlaces Múltiples:")
print(multiple_bonds_stats)
# Out:
# Estadísticas de Número de Átomos y Enlaces:
# BBB+/BBB-              BBB+         BBB-
# NumAtoms count  4956.000000  2851.000000
#          mean     23.908797    32.101017
#          std       8.542891    15.037858
#          min       1.000000     4.000000
#          25%      19.000000    23.000000
#          50%      23.000000    29.000000
#          75%      29.000000    37.000000
#          max      85.000000   136.000000
# NumBonds count  4956.000000  2851.000000
#          mean     26.087974    34.445808
#          std       9.677104    16.199051
#          min       0.000000     3.000000
#          25%      20.000000    25.000000
#          50%      26.000000    31.000000
#          75%      32.000000    40.000000
#          max      85.000000   145.000000
#
# Estadísticas de Conectividad Promedio:
#             count      mean       std  min       25%       50%       75%  \
# BBB+/BBB-
# BBB+       4956.0  2.156927  0.157470  0.0  2.117647  2.181818  2.235294
# BBB-       2851.0  2.138284  0.086689  1.5  2.100000  2.148148  2.190476
#
#                 max
# BBB+/BBB-
# BBB+       2.424242
# BBB-       2.444444
#
# Estadísticas de Número de Anillos:
#             count      mean       std  min  25%  50%  75%   max
# BBB+/BBB-
# BBB+       4956.0  3.202785  1.543399  0.0  2.0  3.0  4.0   9.0
# BBB-       2851.0  3.379867  1.718180  0.0  2.0  3.0  4.0  16.0
#
# Estadísticas de Enlaces Rotacionales:
#             count      mean       std  min  25%  50%  75%   max
# BBB+/BBB-
# BBB+       4956.0  3.920097  2.823512  0.0  2.0  4.0  6.0  27.0
# BBB-       2851.0  6.249035  4.349115  0.0  4.0  6.0  8.0  53.0
#
# Estadísticas de Enlaces Múltiples:
#             count       mean       std  min  25%   50%   75%   max
# BBB+/BBB-
# BBB+       4956.0   9.232042  5.277471  0.0  5.0   8.0  13.0  33.0
# BBB-       2851.0  11.290424  7.099531  0.0  6.5  11.0  15.0  56.0

# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

# Función para calcular el tamaño de la molécula (número de átomos)
def molecule_size(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        return mol.GetNumAtoms()
    return None

# Calcular el tamaño de cada molécula y añadirlo al DataFrame
df['Size'] = df['SMILES'].apply(molecule_size)

# Filtrar moléculas que pasan y no pasan el criterio BBB+
passing = df[df['BBB+/BBB-'] == 'BBB+']
not_passing = df[df['BBB+/BBB-'] == 'BBB-']

# Seleccionar las 5 más largas y más pequeñas
longest_passing = passing.nlargest(5, 'Size')
shortest_passing = passing.nsmallest(5, 'Size')
longest_not_passing = not_passing.nlargest(5, 'Size')
shortest_not_passing = not_passing.nsmallest(5, 'Size')

# Crear una carpeta para guardar las imágenes
output_dir = 'molecule_images'
os.makedirs(output_dir, exist_ok=True)

# Función para guardar moléculas en imágenes 3D (2D renderizado)
def save_molecule_images(smiles_list, titles, file_prefix):
    for smiles, title in zip(smiles_list, titles):
        mol = Chem.MolFromSmiles(smiles)
        if mol:
            mol = Chem.AddHs(mol)
            AllChem.EmbedMolecule(mol)  # Generar una conformación 3D
            img = Draw.MolToImage(mol, size=(300, 300))
            img_file = os.path.join(output_dir, f'{file_prefix}_{title}.png')
            img.save(img_file)
            print(f"Imagen guardada: {img_file}")


# Visualizar imágenes guardadas
fig, axes = plt.subplots(4, 5, figsize=(20, 16))
axes = axes.flatten()
for i, file in enumerate(os.listdir(output_dir)):
    img = mpimg.imread(os.path.join(output_dir, file))
    axes[i].imshow(img)
    axes[i].axis('off')
plt.tight_layout()
plt.show()

# %%
# Función para calcular el tamaño de la molécula (número de átomos)
def molecule_size(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        return mol.GetNumAtoms()
    return None

# Calcular el tamaño de cada molécula y añadirlo al DataFrame
df['Size'] = df['SMILES'].apply(molecule_size)

# Filtrar moléculas que atraviesan y no atraviesan la BBB
passing = df[df['BBB+/BBB-'] == 'BBB+']
not_passing = df[df['BBB+/BBB-'] == 'BBB-']

# Seleccionar las 5 moléculas más grandes que atraviesan la BBB
largest_passing = passing.nlargest(5, 'Size')

# Seleccionar las 5 moléculas más grandes que no atraviesan la BBB
largest_not_passing = not_passing.nlargest(5, 'Size')

# Obtener los SMILES de las moléculas seleccionadas
largest_passing_smiles = largest_passing['SMILES'].tolist()
largest_not_passing_smiles = largest_not_passing['SMILES'].tolist()

# Imprimir los SMILES
print("SMILES de las 5 moléculas más grandes que atraviesan la BBB:")
for smiles in largest_passing_smiles:
    print(smiles)

print("\nSMILES de las 5 moléculas más grandes que no atraviesan la BBB:")
for smiles in largest_not_passing_smiles:
    print(smiles)
# Out:
# SMILES de las 5 moléculas más grandes que atraviesan la BBB:
# C/C=C/C(C)C(O)C1C(=O)NC(CC)C(=O)N(C)CC(=O)N(C)C(CC(C)C)C(=O)NC(C(C)C)C(=O)N(C)C(CC(C)C)C(=O)NC(C)C(=O)NC(C)C(=O)N(C)C(CC(C)C)C(=O)N(C)C(CC(C)C)C(=O)N(C)C(CC(C)C)C(=O)N1C
# C/C=C/CC(C)C(O)C1C(=O)NC(CC)C(=O)N(C)CC(=O)N(C)C(CC(C)C)C(=O)NC(C(C)C)C(=O)N(C)C(CC(C)C)C(=O)NC(C)C(=O)NC(C)C(=O)N(C)C(CC(C)C)C(=O)N(C)C(CC(C)C)C(=O)N(C)C(C(C)C)C(=O)N1C
# C/C=C/C[C@@H](C)[C@@H](O)[C@H]1C(=O)N[C@@H](CC)C(=O)N(C)CC(=O)N(C)[C@@H](CC(C)C)C(=O)N[C@@H](C(C)C)C(=O)N(C)[C@@H](CC(C)C)C(=O)N[C@@H](C)C(=O)N[C@H](C)C(=O)N(C)[C@@H](CC(C)C)C(=O)N(C)[C@@H](CC(C)C)C(=O)N(C)[C@@H](C(C)C)C(=O)N1C
# C/C=C/[C@@H](C)[C@@H](O)[C@@H]1C(=O)N[C@H](CC)C(=O)N(C)CC(=O)N(C)[C@H](CC(C)C)C(=O)N[C@H](C(C)C)C(=O)N(C)[C@H](CC(C)C)C(=O)N[C@H](C)C(=O)N[C@H](C)C(=O)N(C)[C@H](CC(C)C)C(=O)N(C)[C@H](CC(C)C)C(=O)N(C)[C@H](CC(C)C)C(=O)N1C
# C/C=C/[C@@H](C)[C@@H](O)[C@H]1C(=O)N[C@@H](CC)C(=O)N(C)CC(=O)N(C)[C@@H](CC(C)C)C(=O)N[C@@H](C(C)C)C(=O)N(C)[C@@H](CC(C)C)C(=O)N[C@@H](C)C(=O)N[C@H](C)C(=O)N(C)[C@@H](CC(C)C)C(=O)N(C)[C@@H](CC(C)C)C(=O)N(C)[C@@H](CC(C)C)C(=O)N1C
#
# SMILES de las 5 moléculas más grandes que no atraviesan la BBB:
# CC(C)C[C@@H](NC(=O)[C@H](C)NC(=O)CNC(=O)[C@@H](NC=O)C(C)C)C(=O)N[C@@H](C)C(=O)N[C@@H](C(=O)N[C@H](C(=O)N[C@@H](C(=O)N[C@@H](Cc1c[nH]c2ccccc12)C(=O)N[C@H](CC(C)C)C(=O)N[C@@H](Cc1c[nH]c2ccccc12)C(=O)N[C@H](CC(C)C)C(=O)N[C@@H](Cc1c[nH]c2ccccc12)C(=O)N[C@H](CC(C)C)C(=O)N[C@@H](Cc1c[nH]c2ccccc12)C(=O)NCCO)C(C)C)C(C)C)C(C)C
# CC(C)C[C@@H](NC(=O)[C@H](Cc1c[nH]c2ccccc12)NC(=O)[C@@H](CC(C)C)NC(=O)[C@H](Cc1c[nH]c2ccccc12)NC(=O)[C@@H](CC(C)C)NC(=O)[C@H](Cc1c[nH]c2ccccc12)NC(=O)[C@H](NC(=O)[C@@H](NC(=O)[C@H](NC(=O)[C@H](C)NC(=O)[C@@H](CC(C)C)NC(=O)[C@@H](C)NC(=O)CNC(=O)[C@@H](NC=O)C(C)C)C(C)C)C(C)C)C(C)C)C(=O)N[C@@H](Cc1c[nH]c2ccccc12)C(=O)NCCO
# CC(C)CC(NC(=O)C(C)NC(=O)CNC(=O)C(NC=O)C(C)C)C(=O)NC(C)C(=O)NC(C(=O)NC(C(=O)NC(C(=O)NC(Cc1c[nH]c2ccccc12)C(=O)NC(CC(C)C)C(=O)NC(Cc1ccccc1)C(=O)NC(CC(C)C)C(=O)NC(Cc1c[nH]c2ccccc12)C(=O)NC(CC(C)C)C(=O)NC(Cc1c[nH]c2ccccc12)C(=O)NCCO)C(C)C)C(C)C)C(C)C
# CC(C)C[C@H](NC(=O)[C@@H](Cc1c[nH]c2ccccc12)NC(=O)[C@@H](CC(C)C)NC(=O)[C@H](Cc1ccccc1)NC(=O)[C@@H](CC(C)C)NC(=O)[C@H](Cc1c[nH]c2ccccc12)NC(=O)[C@H](NC(=O)[C@H](NC(=O)[C@H](NC(=O)[C@@H](C)NC(=O)[C@@H](CC(C)C)NC(=O)[C@H](C)NC(=O)CNC(=O)[C@H](NC=O)C(C)C)C(C)C)C(C)C)C(C)C)C(=O)N[C@@H](Cc1c[nH]c2ccccc12)C(=O)NCCO
# CCCCCCCCCC(=O)N[C@H]1[C@H](Oc2c3cc4cc2Oc2ccc(cc2Cl)[C@@H](O[C@@H]2O[C@H](CO)[C@@H](O)[C@H](O)[C@H]2NC(C)=O)[C@@H]2NC(=O)[C@H](NC(=O)[C@@H]4NC(=O)[C@H]4NC(=O)[C@@H](Cc5ccc(c(Cl)c5)O3)NC(=O)[C@H](N)c3ccc(O)c(c3)Oc3cc(O)cc4c3)c3ccc(O)c(c3)-c3c(O[C@H]4O[C@H](CO)[C@@H](O)[C@H](O)[C@@H]4O)cc(O)cc3[C@H](C(=O)O)NC2=O)O[C@H](CO)[C@@H](O)[C@@H]1O

# %% [markdown]
#                                         ANALISIS Y REVISION DE VARIABLES NUMERICAS

# %%
# Seleccionar columnas numéricas
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Umbrales de porcentajes para considerar datos atípicos
thresholds = [5, 10, 15, 20, 25]

def identify_outliers(column):
    """ Identifica y cuenta los datos atípicos en una columna usando el rango intercuartil """
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return ((column < lower_bound) | (column > upper_bound)).sum()

# Crear un DataFrame para almacenar el conteo de datos atípicos
outlier_counts = numeric_df.apply(identify_outliers)
total_counts = numeric_df.count()

# Calcular el porcentaje de datos atípicos
outlier_percentage = (outlier_counts / total_counts) * 100

# Inicializar un diccionario para almacenar los resultados
result_counts = {threshold: 0 for threshold in thresholds}

# Contar variables para cada umbral
for threshold in thresholds:
    result_counts[threshold] = (outlier_percentage > threshold).sum()

# Mostrar los resultados
print("Número total de variables con datos atípicos superiores a los umbrales especificados:")
for threshold, count in result_counts.items():
    print(f"Más del {threshold}% de datos atípicos: {count} variables")
# Out:
# Número total de variables con datos atípicos superiores a los umbrales especificados:
# Más del 5% de datos atípicos: 226 variables
# Más del 10% de datos atípicos: 52 variables
# Más del 15% de datos atípicos: 22 variables
# Más del 20% de datos atípicos: 5 variables
# Más del 25% de datos atípicos: 0 variables

# %%
# Obtener una lista de todos los nombres de las columnas
nombres_columnas = df.columns.tolist()

# Definir el número de columnas en la tabla
num_columnas_por_fila = 20  # Ajusta este número según el espacio disponible en tu pantalla

# Dividir los nombres de las columnas en filas
def dividir_lista(lista, tamano_fila):
    return [lista[i:i + tamano_fila] for i in range(0, len(lista), tamano_fila)]

# Crear un DataFrame para cada página
data = dividir_lista(nombres_columnas, num_columnas_por_fila)
df_paginado = pd.DataFrame(data)

# Mostrar el DataFrame utilizando IPython.display
display(df_paginado)
# Out:
#                0             1            2            3            4   \
# 0              N°          name   IUPAC_name       SMILES          CID
# 1       nAromBond         nAtom   nHeavyAtom       nSpiro  nBridgehead
# 2          ATS2dv        ATS3dv       ATS4dv       ATS5dv       ATS6dv
# 3           ATS4Z         ATS5Z        ATS6Z        ATS7Z        ATS8Z
# 4           ATS6v         ATS7v        ATS8v       ATS0se       ATS1se
# 5           ATS8p         ATS0i        ATS1i        ATS2i        ATS3i
# 6          ATSC2c        ATSC3c       ATSC4c       ATSC5c       ATSC6c
# 7          ATSC4d        ATSC5d       ATSC6d       ATSC7d       ATSC8d
# 8          ATSC6m        ATSC7m       ATSC8m       ATSC0v       ATSC1v
# 9         ATSC8se        ATSC0p       ATSC1p       ATSC2p       ATSC3p
# 10       AATSC0dv       AATSC0d      AATSC0Z      AATSC0m      AATSC0v
# 11           RPCG         C1SP1        C2SP1        C1SP2        C2SP2
# 12        Xch-7dv         Xc-3d        Xc-4d        Xc-5d        Xc-6d
# 13          Xp-6d         Xp-7d       Xp-1dv       Xp-2dv       Xp-3dv
# 14             Mi          NsLi        NssBe      NssssBe        NssBH
# 15          NsNH3         NsNH2       NssNH2         NdNH        NssNH
# 16        NssSiH2       NsssSiH      NssssSi        NsPH2        NssPH
# 17         NssAsH        NsssAs      NsssdAs     NsssssAs        NsSeH
# 18           SsLi         SssBe      SssssBe        SssBH        SsssB
# 19          SsNH2        SssNH2         SdNH        SssNH        SaaNH
# 20        SsssSiH       SssssSi        SsPH2        SssPH        SsssP
# 21         SsssAs       SsssdAs     SsssssAs        SsSeH         SdSe
# 22        fragCpx           fMF       nHBAcc       nHBDon          IC0
# 23           CIC4          CIC5         MIC0         MIC1         MIC2
# 24      PEOE_VSA2     PEOE_VSA3    PEOE_VSA4    PEOE_VSA5    PEOE_VSA6
# 25       SMR_VSA9    SlogP_VSA1   SlogP_VSA2   SlogP_VSA3   SlogP_VSA4
# 26    EState_VSA9  EState_VSA10  VSA_EState1  VSA_EState2  VSA_EState3
# 27         TMPC10         piPC1        piPC2        piPC3        piPC4
# 28         n8Ring        n9Ring      n10Ring      n11Ring      n12Ring
# 29        n4aRing       n5aRing      n6aRing      n7aRing      n8aRing
# 30      n12aHRing    nG12aHRing       nARing      n3ARing      n4ARing
# 31       n8AHRing      n9AHRing    n10AHRing    n11AHRing    n12AHRing
# 32       n6FHRing      n7FHRing     n8FHRing     n9FHRing    n10FHRing
# 33      n4FaHRing     n5FaHRing    n6FaHRing    n7FaHRing    n8FaHRing
# 34     nG12FARing      nFAHRing    n4FAHRing    n5FAHRing    n6FAHRing
# 35           GGI4          GGI5         GGI6         GGI7         GGI8
# 36          MWC01         MWC02        MWC03        MWC04        MWC05
# 37         TSRW10            MW          AMW         WPol      Zagreb1
# 38  MultipleBonds          Size         None         None         None
#
#              5            6              7                        8   \
# 0         logBB    BBB+/BBB-          Inchi                reference
# 1       nHetero           nH             nB                       nC
# 2        ATS7dv       ATS8dv          ATS0d                    ATS1d
# 3         ATS0m        ATS1m          ATS2m                    ATS3m
# 4        ATS2se       ATS3se         ATS4se                   ATS5se
# 5         ATS4i        ATS5i          ATS6i                    ATS7i
# 6        ATSC7c       ATSC8c        ATSC0dv                  ATSC1dv
# 7        ATSC0Z       ATSC1Z         ATSC2Z                   ATSC3Z
# 8        ATSC2v       ATSC3v         ATSC4v                   ATSC5v
# 9        ATSC4p       ATSC5p         ATSC6p                   ATSC7p
# 10     AATSC0se      AATSC0p        AATSC0i                 BalabanJ
# 11        C3SP2        C1SP3          C2SP3                    C3SP3
# 12       Xc-3dv       Xc-4dv         Xc-5dv                   Xc-6dv
# 13       Xp-4dv       Xp-5dv         Xp-6dv                   Xp-7dv
# 14        NsssB       NssssB          NsCH3                    NdCH2
# 15        NaaNH          NtN         NsssNH                     NdsN
# 16        NsssP       NdsssP        NsssssP                     NsSH
# 17         NdSe        NssSe          NaaSe                   NdssSe
# 18       SssssB        SsCH3          SdCH2                   SssCH2
# 19          StN       SsssNH           SdsN                     SaaN
# 20       SdsssP      SsssssP           SsSH                      SdS
# 21        SssSe        SaaSe         SdssSe                  SddssSe
# 22          IC1          IC2            IC3                      IC4
# 23         MIC3         MIC4           MIC5                    ZMIC0
# 24    PEOE_VSA7    PEOE_VSA8      PEOE_VSA9               PEOE_VSA10
# 25   SlogP_VSA5   SlogP_VSA6     SlogP_VSA7               SlogP_VSA8
# 26  VSA_EState4  VSA_EState5    VSA_EState6              VSA_EState7
# 27        piPC5        piPC6          piPC7                    piPC8
# 28     nG12Ring       nHRing        n3HRing                  n4HRing
# 29      n9aRing     n10aRing       n11aRing                 n12aRing
# 30      n5ARing      n6ARing        n7ARing                  n8ARing
# 31   nG12AHRing       nFRing        n4FRing                  n5FRing
# 32    n11FHRing    n12FHRing     nG12FHRing                  nFaRing
# 33    n9FaHRing   n10FaHRing     n11FaHRing               n12FaHRing
# 34    n7FAHRing    n8FAHRing      n9FAHRing               n10FAHRing
# 35         GGI9        GGI10           JGI1                     JGI2
# 36        MWC06        MWC07          MWC08                    MWC09
# 37      Zagreb2     mZagreb2  SMILES_length  SMILES_CANONICOS_length
# 38         None         None           None                     None
#
#                           9               10           11                12  \
# 0                      group  SMILES_validos  Tipo_SMILES  SMILES_CANONICOS
# 1                         nN              nO           nS                nP
# 2                      ATS2d           ATS3d        ATS4d             ATS5d
# 3                      ATS4m           ATS5m        ATS6m             ATS7m
# 4                     ATS6se          ATS7se       ATS8se             ATS0p
# 5                      ATS8i         AATS0dv       AATS0d            AATS0Z
# 6                    ATSC2dv         ATSC3dv      ATSC4dv           ATSC5dv
# 7                     ATSC4Z          ATSC5Z       ATSC6Z            ATSC7Z
# 8                     ATSC6v          ATSC7v       ATSC8v           ATSC0se
# 9                     ATSC8p          ATSC0i       ATSC1i            ATSC2i
# 10                   BertzCT          nBonds      nBondsO           nBondsS
# 11                     C4SP3           FCSP3       Xch-3d            Xch-4d
# 12                    Xpc-4d          Xpc-5d       Xpc-6d           Xpc-4dv
# 13                        SZ              Sm           Sv               Sse
# 14                    NssCH2            NtCH        NdsCH             NaaCH
# 15                      NaaN           NsssN        NddsN             NaasN
# 16                       NdS            NssS         NaaS             NdssS
# 17                   NddssSe            NsBr       NsSnH3           NssSnH2
# 18                      StCH           SdsCH        SaaCH            SsssCH
# 19                     SsssN           SddsN        SaasN            SssssN
# 20                      SssS            SaaS        SdssS            SddssS
# 21                      SsBr          SsSnH3      SssSnH2           SsssSnH
# 22                       IC5            TIC0         TIC1              TIC2
# 23                     ZMIC1           ZMIC2        ZMIC3             ZMIC4
# 24                PEOE_VSA11      PEOE_VSA12   PEOE_VSA13          SMR_VSA1
# 25                SlogP_VSA9     SlogP_VSA10  SlogP_VSA11       EState_VSA1
# 26               VSA_EState8     VSA_EState9         MPC2              MPC3
# 27                     piPC9          piPC10      TpiPC10              apol
# 28                   n5HRing         n6HRing      n7HRing           n8HRing
# 29                 nG12aRing         naHRing     n3aHRing          n4aHRing
# 30                   n9ARing        n10ARing     n11ARing          n12ARing
# 31                   n6FRing         n7FRing      n8FRing           n9FRing
# 32                  n4FaRing        n5FaRing     n6FaRing          n7FaRing
# 33               nG12FaHRing         nFARing     n4FARing          n5FARing
# 34                n11FAHRing      n12FAHRing  nG12FAHRing              nRot
# 35                      JGI3            JGI4         JGI5              JGI6
# 36                     MWC10          TMWC10        SRW02             SRW03
# 37  SMILES_ISOMERICOS_length        Symmetry    Is_Chiral          Polarity
# 38                      None            None         None              None
#
#                    13            14            15            16           17  \
# 0   SMILES_ISOMERICOS  SMILES_fixed  SMILES_final          LogP        nAcid
# 1                  nF           nCl           nBr            nI           nX
# 2               ATS6d         ATS7d         ATS8d         ATS0Z        ATS1Z
# 3               ATS8m         ATS0v         ATS1v         ATS2v        ATS3v
# 4               ATS1p         ATS2p         ATS3p         ATS4p        ATS5p
# 5              AATS0m        AATS0v       AATS0se        AATS0p       AATS0i
# 6             ATSC6dv       ATSC7dv       ATSC8dv        ATSC0d       ATSC1d
# 7              ATSC8Z        ATSC0m        ATSC1m        ATSC2m       ATSC3m
# 8             ATSC1se       ATSC2se       ATSC3se       ATSC4se      ATSC5se
# 9              ATSC3i        ATSC4i        ATSC5i        ATSC6i       ATSC7i
# 10            nBondsD       nBondsT       nBondsA       nBondsM     nBondsKS
# 11             Xch-5d        Xch-6d        Xch-7d       Xch-3dv      Xch-4dv
# 12            Xpc-5dv       Xpc-6dv         Xp-1d         Xp-2d        Xp-3d
# 13                 Sp            Si            MZ            Mm           Mv
# 14             NsssCH          NddC          NtsC         NdssC        NaasC
# 15             NssssN          NsOH           NdO          NssO         NaaO
# 16             NddssS          NsCl        NsGeH3       NssGeH2      NsssGeH
# 17            NsssSnH       NssssSn           NsI        NsPbH3      NssPbH2
# 18               SddC          StsC         SdssC         SaasC        SaaaC
# 19               SsOH           SdO          SssO          SaaO          SsF
# 20               SsCl        SsGeH3       SssGeH2       SsssGeH      SssssGe
# 21            SssssSn           SsI        SsPbH3       SssPbH2      SsssPbH
# 22               TIC3          TIC4          TIC5          CIC0         CIC1
# 23              ZMIC5      Lipinski   GhoseFilter  FilterItLogS     VMcGowan
# 24           SMR_VSA2      SMR_VSA3      SMR_VSA4      SMR_VSA5     SMR_VSA6
# 25        EState_VSA2   EState_VSA3   EState_VSA4   EState_VSA5  EState_VSA6
# 26               MPC4          MPC5          MPC6          MPC7         MPC8
# 27               bpol         nRing        n3Ring        n4Ring       n5Ring
# 28            n9HRing      n10HRing      n11HRing      n12HRing    nG12HRing
# 29           n5aHRing      n6aHRing      n7aHRing      n8aHRing     n9aHRing
# 30          nG12ARing       nAHRing      n3AHRing      n4AHRing     n5AHRing
# 31           n10FRing      n11FRing      n12FRing     nG12FRing      nFHRing
# 32           n8FaRing      n9FaRing     n10FaRing     n11FaRing    n12FaRing
# 33           n6FARing      n7FARing      n8FARing      n9FARing    n10FARing
# 34              SLogP           SMR   TopoPSA(NO)       TopoPSA         GGI1
# 35               JGI7          JGI8          JGI9         JGI10        JGT10
# 36              SRW04         SRW05         SRW06         SRW07        SRW08
# 37    ExplicitCharges   DoubleBonds      NumAtoms      NumBonds    RingCount
# 38               None          None          None          None         None
#
#                  18              19
# 0             nBase       nAromAtom
# 1            ATS0dv          ATS1dv
# 2             ATS2Z           ATS3Z
# 3             ATS4v           ATS5v
# 4             ATS6p           ATS7p
# 5            ATSC0c          ATSC1c
# 6            ATSC2d          ATSC3d
# 7            ATSC4m          ATSC5m
# 8           ATSC6se         ATSC7se
# 9            ATSC8i         AATSC0c
# 10         nBondsKD            RNCG
# 11          Xch-5dv         Xch-6dv
# 12            Xp-4d           Xp-5d
# 13              Mse              Mp
# 14            NaaaC          NssssC
# 15              NsF          NsSiH3
# 16          NssssGe          NsAsH2
# 17          NsssPbH         NssssPb
# 18           SssssC           SsNH3
# 19           SsSiH3         SssSiH2
# 20           SsAsH2          SssAsH
# 21          SssssPb         ECIndex
# 22             CIC2            CIC3
# 23        LabuteASA       PEOE_VSA1
# 24         SMR_VSA7        SMR_VSA8
# 25      EState_VSA7     EState_VSA8
# 26             MPC9           MPC10
# 27           n6Ring          n7Ring
# 28           naRing         n3aRing
# 29        n10aHRing       n11aHRing
# 30         n6AHRing        n7AHRing
# 31         n4FHRing        n5FHRing
# 32       nG12FaRing        nFaHRing
# 33        n11FARing       n12FARing
# 34             GGI2            GGI3
# 35         Diameter          Radius
# 36            SRW09           SRW10
# 37  AvgConnectivity  RotatableBonds
# 38             None            None

# %%
import pandas as pd
from IPython.display import display

# Dividir la base de datos en dos grupos: BBB+ y BBB-
bbb_positivo = df[df["BBB+/BBB-"] == "BBB+"]
bbb_negativo = df[df["BBB+/BBB-"] == "BBB-"]

# Contar la cantidad de registros en cada grupo
cantidad_bbb_positivo = len(bbb_positivo)
cantidad_bbb_negativo = len(bbb_negativo)

# Imprimir la cantidad de registros en cada grupo
print("Cantidad de registros con BBB+: ", cantidad_bbb_positivo)
print("Cantidad de registros con BBB-: ", cantidad_bbb_negativo)

# Realizar un resumen de estadísticas descriptivas para cada grupo
resumen_bbb_positivo = bbb_positivo.describe()
resumen_bbb_negativo = bbb_negativo.describe()

# Imprimir los resúmenes de estadísticas descriptivas utilizando display
print("\nResumen de estadísticas descriptivas para BBB+:")
display(resumen_bbb_positivo)

print("\nResumen de estadísticas descriptivas para BBB-:")
display(resumen_bbb_negativo)
# Out:
# Cantidad de registros con BBB+:  4956
# Cantidad de registros con BBB-:  2851
#
# Resumen de estadísticas descriptivas para BBB+:
#                 N°           CID       logBB         LogP        nAcid  \
# count  4956.000000  4.001000e+03  930.000000  4956.000000  4956.000000
# mean   3517.557304  2.075244e+07    0.110860     2.874041     0.054278
# std    2332.830515  3.519789e+07    0.577206     1.578878     0.260559
# min     129.000000  1.100000e+01   -1.000000    -4.375400     0.000000
# 25%    1481.750000  3.776700e+04   -0.290000     1.843700     0.000000
# 50%    3144.500000  3.010454e+06    0.075000     2.923300     0.000000
# 75%    5758.000000  1.843577e+07    0.507500     3.962500     0.000000
# max    7805.000000  1.543952e+08    1.700000    10.056300     3.000000
#
#              nBase    nAromAtom    nAromBond        nAtom   nHeavyAtom  ...  \
# count  4956.000000  4956.000000  4956.000000  4956.000000  4956.000000  ...
# mean      0.593624     7.215698     7.334140    47.141646    23.908797  ...
# std       0.678866     5.678583     5.822373    17.565909     8.542891  ...
# min       0.000000     0.000000     0.000000     1.000000     1.000000  ...
# 25%       0.000000     0.000000     0.000000    36.000000    19.000000  ...
# 50%       1.000000     6.000000     6.000000    46.000000    23.000000  ...
# 75%       1.000000    12.000000    12.000000    57.000000    29.000000  ...
# max       6.000000    28.000000    28.000000   196.000000    85.000000  ...
#
#           Symmetry     Polarity  DoubleBonds     NumAtoms     NumBonds  \
# count  4956.000000  4956.000000  4956.000000  4956.000000  4956.000000
# mean      3.202785     2.874041     1.862389    23.908797    26.087974
# std       1.543399     1.578878     1.751237     8.542891     9.677104
# min       0.000000    -4.375400     0.000000     1.000000     0.000000
# 25%       2.000000     1.843700     1.000000    19.000000    20.000000
# 50%       3.000000     2.923300     1.000000    23.000000    26.000000
# 75%       4.000000     3.962500     3.000000    29.000000    32.000000
# max       9.000000    10.056300    12.000000    85.000000    85.000000
#
#          RingCount  AvgConnectivity  RotatableBonds  MultipleBonds  \
# count  4956.000000      4956.000000     4956.000000    4956.000000
# mean      3.202785         2.156927        3.920097       9.232042
# std       1.543399         0.157470        2.823512       5.277471
# min       0.000000         0.000000        0.000000       0.000000
# 25%       2.000000         2.117647        2.000000       5.000000
# 50%       3.000000         2.181818        4.000000       8.000000
# 75%       4.000000         2.235294        6.000000      13.000000
# max       9.000000         2.424242       27.000000      33.000000
#
#               Size
# count  4956.000000
# mean     23.908797
# std       8.542891
# min       1.000000
# 25%      19.000000
# 50%      23.000000
# 75%      29.000000
# max      85.000000
#
# [8 rows x 745 columns]
# Resumen de estadísticas descriptivas para BBB-:
#                 N°           CID       logBB         LogP        nAcid  \
# count  2851.000000  2.169000e+03  128.000000  2851.000000  2851.000000
# mean   4575.767801  2.095752e+07   -1.449141     1.455545     0.494213
# std    1934.023437  3.690087e+07    0.329777     2.755004     0.835328
# min       1.000000  8.500000e+01   -2.690000    -8.895300     0.000000
# 25%    3299.500000  5.677000e+03   -1.570000     0.001300     0.000000
# 50%    5068.000000  4.439530e+05   -1.375000     1.458200     0.000000
# 75%    5860.500000  1.675882e+07   -1.230000     3.111100     1.000000
# max    7807.000000  1.547351e+08   -1.010000    12.605800     8.000000
#
#              nBase    nAromAtom    nAromBond        nAtom   nHeavyAtom  ...  \
# count  2851.000000  2851.000000  2851.000000  2851.000000  2851.000000  ...
# mean      0.823571     7.841810     7.990179    60.845317    32.101017  ...
# std       1.237181     6.374721     6.561710    31.794023    15.037858  ...
# min       0.000000     0.000000     0.000000     9.000000     4.000000  ...
# 25%       0.000000     5.000000     5.000000    42.000000    23.000000  ...
# 50%       0.000000     6.000000     6.000000    53.000000    29.000000  ...
# 75%       1.000000    12.000000    12.000000    69.000000    37.000000  ...
# max      10.000000    44.000000    46.000000   276.000000   136.000000  ...
#
#           Symmetry     Polarity  DoubleBonds     NumAtoms     NumBonds  \
# count  2851.000000  2851.000000  2851.000000  2851.000000  2851.000000
# mean      3.379867     1.455545     3.262364    32.101017    34.445808
# std       1.718180     2.755004     2.469161    15.037858    16.199051
# min       0.000000    -8.895300     0.000000     4.000000     3.000000
# 25%       2.000000     0.001300     1.000000    23.000000    25.000000
# 50%       3.000000     1.458200     3.000000    29.000000    31.000000
# 75%       4.000000     3.111100     5.000000    37.000000    40.000000
# max      16.000000    12.605800    16.000000   136.000000   145.000000
#
#          RingCount  AvgConnectivity  RotatableBonds  MultipleBonds  \
# count  2851.000000      2851.000000     2851.000000    2851.000000
# mean      3.379867         2.138284        6.249035      11.290424
# std       1.718180         0.086689        4.349115       7.099531
# min       0.000000         1.500000        0.000000       0.000000
# 25%       2.000000         2.100000        4.000000       6.500000
# 50%       3.000000         2.148148        6.000000      11.000000
# 75%       4.000000         2.190476        8.000000      15.000000
# max      16.000000         2.444444       53.000000      56.000000
#
#               Size
# count  2851.000000
# mean     32.101017
# std      15.037858
# min       4.000000
# 25%      23.000000
# 50%      29.000000
# 75%      37.000000
# max     136.000000
#
# [8 rows x 745 columns]

# %% [markdown]
# Se seleccionan los descriptores HBD, HBA, Número de Átomos Pesados, Peso Molecular (MW), Número de Enlaces Pesados y logBB porque son propiedades clave que influyen en la capacidad de una molécula para atravesar la barrera hematoencefálica (BBB). HBD y HBA afectan la formación de puentes de hidrógeno, crucial para la interacción con la BBB. El Número de Átomos Pesados y el Peso Molecular están relacionados con el tamaño y la complejidad de la molécula, que puede limitar su permeabilidad. Número de Enlaces Pesados indica la complejidad estructural, mientras que logBB mide directamente la capacidad de la molécula para penetrar la BBB. Analizar estos descriptores permite identificar patrones críticos para desarrollar modelos predictivos precisos y optimizar el diseño de fármacos efectivos.

# %%
import pandas as pd
from scipy import stats # type: ignore

# Dividir la base de datos en dos grupos: BBB+ y BBB-
bbb_positivo = df[df["BBB+/BBB-"] == "BBB+"].copy()
bbb_negativo = df[df["BBB+/BBB-"] == "BBB-"].copy()

# Contar la cantidad de registros en cada grupo
cantidad_bbb_positivo = len(bbb_positivo)
cantidad_bbb_negativo = len(bbb_negativo)

# Imprimir la cantidad de registros en cada grupo
print("Cantidad de registros con BBB+: {}".format(cantidad_bbb_positivo))
print("Cantidad de registros con BBB-: {}".format(cantidad_bbb_negativo))

# Variables de interés
variables_interes = ['nHBDon', 'nHBAcc', 'nHeavyAtom', 'MW', 'nBonds', 'logBB']

# Asegurarse de que las columnas son numéricas
for var in variables_interes:
    bbb_positivo[var] = pd.to_numeric(bbb_positivo[var], errors='coerce')
    bbb_negativo[var] = pd.to_numeric(bbb_negativo[var], errors='coerce')

# Remover filas con valores NaN
bbb_positivo.dropna(subset=variables_interes, inplace=True)
bbb_negativo.dropna(subset=variables_interes, inplace=True)

def calcular_estadisticas_completas(df, variables):
    estadisticas = {}
    for var in variables:
        estadisticas[var] = {
            'Media': df[var].mean(),
            'Mediana': df[var].median(),
            'Moda': df[var].mode().iloc[0] if not df[var].mode().empty else float('nan'),
            'Desviación Estándar': df[var].std(),
            'Varianza': df[var].var(),
            'Mínimo': df[var].min(),
            'Máximo': df[var].max(),
            'Rango': df[var].max() - df[var].min(),
            'Percentil 25': df[var].quantile(0.25),
            'Percentil 50': df[var].quantile(0.5),
            'Percentil 75': df[var].quantile(0.75),
            'Skewness': df[var].skew(),
            'Kurtosis': df[var].kurt()
        }
    return pd.DataFrame(estadisticas)

# Calcular estadísticas completas para cada grupo
estadisticas_bbb_positivo = calcular_estadisticas_completas(bbb_positivo, variables_interes)
estadisticas_bbb_negativo = calcular_estadisticas_completas(bbb_negativo, variables_interes)

# Mostrar estadísticas completas para BBB+
print("\nEstadísticas descriptivas completas para BBB+:")
print(estadisticas_bbb_positivo.to_string(index=True))

# Mostrar estadísticas completas para BBB-
print("\nEstadísticas descriptivas completas para BBB-:")
print(estadisticas_bbb_negativo.to_string(index=True))

# Función para comparar grupos y generar un resumen de diferencias
def analizar_diferencias(df1, df2, variables):
    diferencias = {}
    for var in variables:
        media1 = df1[var].mean()
        media2 = df2[var].mean()
        t_stat, p_value = stats.ttest_ind(df1[var], df2[var])
        diferencias[var] = {
            'Media BBB+': media1,
            'Media BBB-': media2,
            'Diferencia de Medias': media1 - media2,
            't-stat': t_stat,
            'p-value': p_value
        }
    return pd.DataFrame(diferencias)

# Analizar diferencias entre BBB+ y BBB-
diferencias_estadisticas = analizar_diferencias(bbb_positivo, bbb_negativo, variables_interes)

# Mostrar diferencias estadísticas
print("\nDiferencias estadísticas entre BBB+ y BBB-:")
print(diferencias_estadisticas.to_string(index=True))

# Generar conclusiones basadas en el análisis
conclusiones = []
for var in variables_interes:
    media_pos = diferencias_estadisticas.at['Media BBB+', var]
    media_neg = diferencias_estadisticas.at['Media BBB-', var]
    diff_media = diferencias_estadisticas.at['Diferencia de Medias', var]
    p_value = diferencias_estadisticas.at['p-value', var]

    if p_value < 0.05:
        conclusion = f"Para {var}, hay una diferencia significativa entre BBB+ y BBB- (p < 0.05)."
        if diff_media > 0:
            conclusion += f" La media de BBB+ ({media_pos}) es mayor que la media de BBB- ({media_neg})."
        else:
            conclusion += f" La media de BBB+ ({media_pos}) es menor que la media de BBB- ({media_neg})."
    else:
        conclusion = f"Para {var}, no hay una diferencia significativa entre BBB+ y BBB- (p >= 0.05)."

    conclusiones.append(conclusion)

# Imprimir conclusiones
print("\nConclusiones:")
for conclusion in conclusiones:
    print(conclusion)
# Out:
# Cantidad de registros con BBB+: 4956
# Cantidad de registros con BBB-: 2851
#
# Estadísticas descriptivas completas para BBB+:
#                        nHBDon     nHBAcc  nHeavyAtom            MW      nBonds     logBB
# Media                1.178495   3.729032   21.827957    311.022278   44.009677  0.110860
# Mediana              1.000000   3.000000   22.000000    304.077315   44.000000  0.075000
# Moda                 1.000000   3.000000   22.000000    229.017353   45.000000 -0.300000
# Desviación Estándar  1.212764   2.462576   11.043825    152.401932   23.641449  0.577206
# Varianza             1.470796   6.064280  121.966064  23226.348759  558.918098  0.333166
# Mínimo               0.000000   0.000000    1.000000      7.016005    0.000000 -1.000000
# Máximo               8.000000  14.000000   85.000000   1201.841368  196.000000  1.700000
# Rango                8.000000  14.000000   84.000000   1194.825363  196.000000  2.700000
# Percentil 25         0.000000   2.000000   15.000000    223.949957   29.000000 -0.290000
# Percentil 50         1.000000   3.000000   22.000000    304.077315   44.000000  0.075000
# Percentil 75         2.000000   5.000000   27.000000    385.213856   55.000000  0.507500
# Skewness             1.632300   1.202444    1.529958      1.643474    2.033987  0.189904
# Kurtosis             4.435920   2.765169    6.860365      7.448072   10.745722 -0.512421
#
# Estadísticas descriptivas completas para BBB-:
#                         nHBDon     nHBAcc  nHeavyAtom            MW      nBonds     logBB
# Media                 2.492188   6.101562   26.546875    382.650833   51.250000 -1.449141
# Mediana               2.000000   6.000000   23.000000    341.085953   44.000000 -1.375000
# Moda                  2.000000   6.000000   15.000000    314.141262   43.000000 -1.300000
# Desviación Estándar   2.244840   3.724445   13.944694    197.924389   28.651311  0.329777
# Varianza              5.039309  13.871494  194.454478  39174.063593  820.897638  0.108753
# Mínimo                0.000000   1.000000   10.000000    137.047678   16.000000 -2.690000
# Máximo               21.000000  29.000000  127.000000   1800.629293  241.000000 -1.010000
# Rango                21.000000  28.000000  117.000000   1663.581615  225.000000  1.680000
# Percentil 25          1.000000   4.000000   17.000000    252.139473   33.000000 -1.570000
# Percentil 50          2.000000   6.000000   23.000000    341.085953   44.000000 -1.375000
# Percentil 75          3.000000   7.000000   32.250000    454.171316   59.000000 -1.230000
# Skewness              4.817278   2.350932    3.420004      3.317624    3.008690 -1.268069
# Kurtosis             36.127260  10.672198   20.653768     20.018783   15.046477  1.615963
#
# Diferencias estadísticas entre BBB+ y BBB-:
#                             nHBDon        nHBAcc  nHeavyAtom          MW     nBonds          logBB
# Media BBB+            1.178495e+00  3.729032e+00   21.827957  311.022278  44.009677   1.108602e-01
# Media BBB-            2.492188e+00  6.101562e+00   26.546875  382.650833  51.250000  -1.449141e+00
# Diferencia de Medias -1.313693e+00 -2.372530e+00   -4.718918  -71.628555  -7.240323   1.560001e+00
# t-stat               -1.010939e+01 -9.509696e+00   -4.378597   -4.791484  -3.160670   2.990488e+01
# p-value               5.369343e-23  1.244596e-20    0.000013    0.000002   0.001619  7.579226e-143
#
# Conclusiones:
# Para nHBDon, hay una diferencia significativa entre BBB+ y BBB- (p < 0.05). La media de BBB+ (1.178494623655914) es menor que la media de BBB- (2.4921875).
# Para nHBAcc, hay una diferencia significativa entre BBB+ y BBB- (p < 0.05). La media de BBB+ (3.729032258064516) es menor que la media de BBB- (6.1015625).
# Para nHeavyAtom, hay una diferencia significativa entre BBB+ y BBB- (p < 0.05). La media de BBB+ (21.827956989247312) es menor que la media de BBB- (26.546875).
# Para MW, hay una diferencia significativa entre BBB+ y BBB- (p < 0.05). La media de BBB+ (311.02227820960167) es menor que la media de BBB- (382.6508329356738).
# Para nBonds, hay una diferencia significativa entre BBB+ y BBB- (p < 0.05). La media de BBB+ (44.00967741935484) es menor que la media de BBB- (51.25).
# Para logBB, hay una diferencia significativa entre BBB+ y BBB- (p < 0.05). La media de BBB+ (0.11086021505376344) es mayor que la media de BBB- (-1.449140625).

# %% [markdown]
# Para abordar el desbalance en los grupos BBB+ y BBB- y hacer una comparación justa, puedes usar técnicas de muestreo para equilibrar los grupos antes de realizar el análisis estadístico. Aquí te muestro cómo puedes modificar tu script para igualar el tamaño de los grupos utilizando un muestreo aleatorio:

# %%
import pandas as pd
from scipy import stats # type: ignore


# Dividir la base de datos en dos grupos: BBB+ y BBB-
bbb_positivo = df[df["BBB+/BBB-"] == "BBB+"].copy()
bbb_negativo = df[df["BBB+/BBB-"] == "BBB-"].copy()

# Contar la cantidad de registros en cada grupo
cantidad_bbb_positivo = len(bbb_positivo)
cantidad_bbb_negativo = len(bbb_negativo)

print("Cantidad de registros con BBB+: {}".format(cantidad_bbb_positivo))
print("Cantidad de registros con BBB-: {}".format(cantidad_bbb_negativo))

# Determinar el tamaño del grupo más pequeño
tamano_minimo = min(cantidad_bbb_positivo, cantidad_bbb_negativo)

# Muestrear aleatoriamente para igualar el tamaño de los grupos
bbb_positivo_muestreado = bbb_positivo.sample(n=tamano_minimo, random_state=42)
bbb_negativo_muestreado = bbb_negativo.sample(n=tamano_minimo, random_state=42)

# Variables de interés
variables_interes = ['nHBDon', 'nHBAcc', 'nHeavyAtom', 'MW', 'nBonds', 'logBB']

# Asegurarse de que las columnas son numéricas
for var in variables_interes:
    bbb_positivo_muestreado[var] = pd.to_numeric(bbb_positivo_muestreado[var], errors='coerce')
    bbb_negativo_muestreado[var] = pd.to_numeric(bbb_negativo_muestreado[var], errors='coerce')

# Remover filas con valores NaN
bbb_positivo_muestreado.dropna(subset=variables_interes, inplace=True)
bbb_negativo_muestreado.dropna(subset=variables_interes, inplace=True)

def calcular_estadisticas_completas(df, variables):
    estadisticas = {}
    for var in variables:
        estadisticas[var] = {
            'Media': df[var].mean(),
            'Mediana': df[var].median(),
            'Moda': df[var].mode().iloc[0] if not df[var].mode().empty else float('nan'),
            'Desviación Estándar': df[var].std(),
            'Varianza': df[var].var(),
            'Mínimo': df[var].min(),
            'Máximo': df[var].max(),
            'Rango': df[var].max() - df[var].min(),
            'Percentil 25': df[var].quantile(0.25),
            'Percentil 50': df[var].quantile(0.5),
            'Percentil 75': df[var].quantile(0.75),
            'Skewness': df[var].skew(),
            'Kurtosis': df[var].kurt()
        }
    return pd.DataFrame(estadisticas)

# Calcular estadísticas completas para cada grupo
estadisticas_bbb_positivo = calcular_estadisticas_completas(bbb_positivo_muestreado, variables_interes)
estadisticas_bbb_negativo = calcular_estadisticas_completas(bbb_negativo_muestreado, variables_interes)

# Mostrar estadísticas completas para BBB+
print("\nEstadísticas descriptivas completas para BBB+:")
print(estadisticas_bbb_positivo.to_string(index=True))

# Mostrar estadísticas completas para BBB-
print("\nEstadísticas descriptivas completas para BBB-:")
print(estadisticas_bbb_negativo.to_string(index=True))

# Función para comparar grupos y generar un resumen de diferencias
def analizar_diferencias(df1, df2, variables):
    diferencias = {}
    for var in variables:
        media1 = df1[var].mean()
        media2 = df2[var].mean()
        t_stat, p_value = stats.ttest_ind(df1[var], df2[var])
        diferencias[var] = {
            'Media BBB+': media1,
            'Media BBB-': media2,
            'Diferencia de Medias': media1 - media2,
            't-stat': t_stat,
            'p-value': p_value
        }
    return pd.DataFrame(diferencias)

# Analizar diferencias entre BBB+ y BBB-
diferencias_estadisticas = analizar_diferencias(bbb_positivo_muestreado, bbb_negativo_muestreado, variables_interes)

# Mostrar diferencias estadísticas
print("\nDiferencias estadísticas entre BBB+ y BBB-:")
print(diferencias_estadisticas.to_string(index=True))

# Generar conclusiones basadas en el análisis
conclusiones = []
for var in variables_interes:
    media_pos = diferencias_estadisticas.at['Media BBB+', var]
    media_neg = diferencias_estadisticas.at['Media BBB-', var]
    diff_media = diferencias_estadisticas.at['Diferencia de Medias', var]
    p_value = diferencias_estadisticas.at['p-value', var]

    if p_value < 0.05:
        conclusion = f"Para {var}, hay una diferencia significativa entre BBB+ y BBB- (p < 0.05)."
        if diff_media > 0:
            conclusion += f" La media de BBB+ ({media_pos}) es mayor que la media de BBB- ({media_neg})."
        else:
            conclusion += f" La media de BBB+ ({media_pos}) es menor que la media de BBB- ({media_neg})."
    else:
        conclusion = f"Para {var}, no hay una diferencia significativa entre BBB+ y BBB- (p >= 0.05)."

    conclusiones.append(conclusion)

# Imprimir conclusiones
print("\nConclusiones:")
for conclusion in conclusiones:
    print(conclusion)
# Out:
# Cantidad de registros con BBB+: 4956
# Cantidad de registros con BBB-: 2851
#
# Estadísticas descriptivas completas para BBB+:
#                        nHBDon     nHBAcc  nHeavyAtom            MW      nBonds     logBB
# Media                1.197719   3.739544   21.813688    311.026487   44.077947  0.094506
# Mediana              1.000000   3.000000   22.000000    302.614957   43.000000  0.030000
# Moda                 0.000000   3.000000   22.000000   1201.841368   45.000000 -0.100000
# Desviación Estándar  1.285403   2.521269   11.603098    160.102821   25.109050  0.564576
# Varianza             1.652261   6.356795  134.631888  25632.913256  630.464389  0.318746
# Mínimo               0.000000   0.000000    1.000000     18.010565    0.000000 -1.000000
# Máximo               8.000000  14.000000   85.000000   1201.841368  196.000000  1.440000
# Rango                8.000000  14.000000   84.000000   1183.830803  196.000000  2.440000
# Percentil 25         0.000000   2.000000   15.000000    218.110810   29.000000 -0.300000
# Percentil 50         1.000000   3.000000   22.000000    302.614957   43.000000  0.030000
# Percentil 75         2.000000   5.000000   27.000000    389.891410   56.000000  0.507500
# Skewness             1.652380   1.246435    1.769846      1.895921    2.329885  0.159648
# Kurtosis             4.003621   2.705849    7.802943      8.490777   11.936056 -0.685947
#
# Estadísticas descriptivas completas para BBB-:
#                         nHBDon     nHBAcc  nHeavyAtom            MW      nBonds     logBB
# Media                 2.492188   6.101562   26.546875    382.650833   51.250000 -1.449141
# Mediana               2.000000   6.000000   23.000000    341.085953   44.000000 -1.375000
# Moda                  2.000000   6.000000   15.000000    314.141262   43.000000 -1.300000
# Desviación Estándar   2.244840   3.724445   13.944694    197.924389   28.651311  0.329777
# Varianza              5.039309  13.871494  194.454478  39174.063593  820.897638  0.108753
# Mínimo                0.000000   1.000000   10.000000    137.047678   16.000000 -2.690000
# Máximo               21.000000  29.000000  127.000000   1800.629293  241.000000 -1.010000
# Rango                21.000000  28.000000  117.000000   1663.581615  225.000000  1.680000
# Percentil 25          1.000000   4.000000   17.000000    252.139473   33.000000 -1.570000
# Percentil 50          2.000000   6.000000   23.000000    341.085953   44.000000 -1.375000
# Percentil 75          3.000000   7.000000   32.250000    454.171316   59.000000 -1.230000
# Skewness              4.817278   2.350932    3.420004      3.317624    3.008690 -1.268069
# Kurtosis             36.127260  10.672198   20.653768     20.018783   15.046477  1.615963
#
# Diferencias estadísticas entre BBB+ y BBB-:
#                             nHBDon        nHBAcc  nHeavyAtom          MW     nBonds          logBB
# Media BBB+            1.197719e+00  3.739544e+00   21.813688  311.026487  44.077947   9.450570e-02
# Media BBB-            2.492188e+00  6.101562e+00   26.546875  382.650833  51.250000  -1.449141e+00
# Diferencia de Medias -1.294469e+00 -2.362019e+00   -4.733187  -71.624346  -7.172053   1.543646e+00
# t-stat               -8.637855e+00 -8.569860e+00   -3.970668   -4.322178  -2.816489   2.971374e+01
# p-value               4.397945e-17  7.488732e-17    0.000080    0.000018   0.005002  2.490413e-123
#
# Conclusiones:
# Para nHBDon, hay una diferencia significativa entre BBB+ y BBB- (p < 0.05). La media de BBB+ (1.1977186311787071) es menor que la media de BBB- (2.4921875).
# Para nHBAcc, hay una diferencia significativa entre BBB+ y BBB- (p < 0.05). La media de BBB+ (3.7395437262357416) es menor que la media de BBB- (6.1015625).
# Para nHeavyAtom, hay una diferencia significativa entre BBB+ y BBB- (p < 0.05). La media de BBB+ (21.813688212927758) es menor que la media de BBB- (26.546875).
# Para MW, hay una diferencia significativa entre BBB+ y BBB- (p < 0.05). La media de BBB+ (311.0264873927621) es menor que la media de BBB- (382.6508329356738).
# Para nBonds, hay una diferencia significativa entre BBB+ y BBB- (p < 0.05). La media de BBB+ (44.07794676806083) es menor que la media de BBB- (51.25).
# Para logBB, hay una diferencia significativa entre BBB+ y BBB- (p < 0.05). La media de BBB+ (0.09450570342205324) es mayor que la media de BBB- (-1.449140625).

# %%
import seaborn as sns

# Seleccionar las columnas de interés
columnas_interes = ['nHBDon', 'nHBAcc', 'nHeavyAtom', 'MW', 'nBonds', 'logBB']

# Filtrar el DataFrame para las columnas seleccionadas
df_interes = df[columnas_interes]

# Crear una matriz de correlación
correlation_matrix = df_interes.corr()

# Configurar el tamaño de la figura
plt.figure(figsize=(10, 8))

# Crear el correlograma usando seaborn
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, linecolor='black')

# Configurar los títulos y etiquetas
plt.title('Correlograma de Descriptores Moleculares', fontsize=16)

# Mostrar la gráfica
plt.show()

# %%
# Seleccionar las columnas de interés
columnas_interes = ['nHBDon', 'nHBAcc', 'nHeavyAtom', 'MW', 'nBonds', 'logBB']

# Filtrar el DataFrame para las columnas seleccionadas
df_interes = df[columnas_interes]

# Configurar el tamaño de la figura
plt.figure(figsize=(14, 10))

# Crear gráficos de barras para cada variable
for i, columna in enumerate(columnas_interes, start=1):
    plt.subplot(2, 3, i)
    sns.histplot(df_interes[columna], bins=30, color='royalblue', kde=True, line_kws={'color': 'crimson', 'linewidth': 2.5})
    plt.title(f'Distribución de {columna}')
    plt.xlabel(columna)
    plt.ylabel('Frecuencia')

# Ajustar el diseño para que no se sobrepongan las gráficas
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Seleccionar las columnas de interés
columnas_interes = ['nHBDon', 'nHBAcc', 'nHeavyAtom', 'MW', 'nBonds', 'logBB']

# Filtrar el DataFrame para las columnas seleccionadas
df_interes = df[columnas_interes + ['BBB+/BBB-']]

# Configurar el tamaño de la figura
plt.figure(figsize=(14, 10))

# Crear gráficos de barras para cada variable
for i, columna in enumerate(columnas_interes, start=1):
    plt.subplot(2, 3, i)
    sns.histplot(data=df_interes, x=columna, hue='BBB+/BBB-', multiple='stack', palette='Set1', bins=30, alpha=0.7)
    plt.title(f'Distribución de {columna}')
    plt.xlabel(columna)
    plt.ylabel('Frecuencia')

# Ajustar el diseño para que no se sobrepongan las gráficas
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#  Distribucion d e'LogP' 
df['LogP'] = df['LogP'].astype(float)  # Asegúrate de que 'LogP' sea numérico

# Configurar el tamaño de la figura
plt.figure(figsize=(14, 6))

# Gráfico 1: Distribución general de 'LogP'
plt.subplot(1, 2, 1)
sns.histplot(df['LogP'], bins=30, color='skyblue', kde=True, line_kws={'color': 'black'})
plt.title('Distribución General de LogP')
plt.xlabel('LogP')
plt.ylabel('Frecuencia')

# Gráfico 2: Distribución de 'LogP' diferenciada por BBB+/BBB-
plt.subplot(1, 2, 2)
sns.histplot(df, x='LogP', hue='BBB+/BBB-', multiple='stack', palette={'BBB+': 'lightcoral', 'BBB-': 'lightgreen'}, bins=30, kde=True, line_kws={'color': 'black'})
plt.title('Distribución de LogP por BBB+/BBB-')
plt.xlabel('LogP')
plt.ylabel('Frecuencia')

# Ajustar el diseño para que no se sobrepongan las gráficas
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np

# Filtra solo las columnas numéricas
VAR_num = df.select_dtypes(include=[np.number])

# Excluye la columna 'CID' si está en el DataFrame numérico
if 'CID' in VAR_num.columns:
    VAR_num = VAR_num.drop(columns=['CID'])

# Guarda VAR_num en un archivo CSV
try:
    VAR_num.to_csv('VAR_num.csv', index=False)
    print("Archivo CSV guardado correctamente.")
except Exception as e:
    print(f"Error al guardar el archivo CSV: {e}")
# Out:
# Error al guardar el archivo CSV: 'Index' object has no attribute '_format_native_types'

# %%
import pandas as pd
import numpy as np

# Calcula la matriz de correlación
correlation_matrix = VAR_num.corr().abs()

# Crear una máscara para evitar contar la correlación de una variable consigo misma
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool), k=1)

# Función para contar correlaciones superiores a un umbral
def count_correlations_above_threshold(corr_matrix, threshold):
    return (corr_matrix[mask] > threshold).sum()

# Umbrales de correlación
thresholds = [0.10, 0.95, 0.90, 0.85, 0.80, 0.75, 0.70]

# Calcular y mostrar el número total de correlaciones para cada umbral
results = {threshold: count_correlations_above_threshold(correlation_matrix, threshold) for threshold in thresholds}

# Imprimir solo los valores
for threshold, count in results.items():
    print(f'Correlación > {threshold * 100}%: {count}')
# Out:
# Correlación > 10.0%: N°                 118045
# logBB              137366
# LogP               135020
# nAcid               79191
# nBase              119190
#                     ...
# RingCount          169629
# AvgConnectivity    141159
# RotatableBonds     162380
# MultipleBonds      159093
# Size               172966
# Length: 744, dtype: int64
# Correlación > 95.0%: N°                  1485
# logBB               1485
# LogP                 815
# nAcid                740
# nBase                739
#                    ...
# RingCount            218
# AvgConnectivity        3
# RotatableBonds        69
# MultipleBonds        542
# Size               24453
# Length: 744, dtype: int64
# Correlación > 90.0%: N°                  1485
# logBB               1485
# LogP                 815
# nAcid                740
# nBase                739
#                    ...
# RingCount            714
# AvgConnectivity        3
# RotatableBonds        69
# MultipleBonds       3279
# Size               58379
# Length: 744, dtype: int64
# Correlación > 85.0%: N°                  1485
# logBB               1485
# LogP                 815
# nAcid                740
# nBase                739
#                    ...
# RingCount           2826
# AvgConnectivity        3
# RotatableBonds        69
# MultipleBonds       3717
# Size               67654
# Length: 744, dtype: int64
# Correlación > 80.0%: N°                  1485
# logBB               1485
# LogP                1098
# nAcid                740
# nBase                739
#                    ...
# RingCount           5224
# AvgConnectivity       64
# RotatableBonds        69
# MultipleBonds       4503
# Size               72677
# Length: 744, dtype: int64
# Correlación > 75.0%: N°                  1485
# logBB               1485
# LogP                1098
# nAcid                740
# nBase                739
#                    ...
# RingCount          10611
# AvgConnectivity     1090
# RotatableBonds        69
# MultipleBonds       5428
# Size               78021
# Length: 744, dtype: int64
# Correlación > 70.0%: N°                  1485
# logBB               1485
# LogP                1098
# nAcid                740
# nBase                739
#                    ...
# RingCount          25254
# AvgConnectivity     2036
# RotatableBonds        69
# MultipleBonds       5814
# Size               82273
# Length: 744, dtype: int64
